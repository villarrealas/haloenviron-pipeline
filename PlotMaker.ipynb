# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
fmttag = 'pdf'

l0500_d340= np.loadtxt('l0500_m3e12_d340b_nolog.dat')
l0500_d200= np.loadtxt('l0500_m4e12_d200b_nolog.dat')
l0500_d100= np.loadtxt('l0500_m5e12_d100b_nolog.dat')
l0500_d75=np.loadtxt('l0500_m6e12_d75b_nolog.dat')
l0500_d50=np.loadtxt('l0500_m7e12_d50b_nolog.dat')

l0500_d340_xicomp_cnfw = (l0500_d340[:,5]-l0500_d340[:,3])/l0500_d340[:,1]
l0500_d200_xicomp_cnfw = (l0500_d200[:,5]-l0500_d200[:,3])/l0500_d200[:,1]
l0500_d100_xicomp_cnfw = (l0500_d100[:,5]-l0500_d100[:,3])/l0500_d100[:,1]
l0500_d75_xicomp_cnfw = (l0500_d75[:,5]-l0500_d75[:,3])/l0500_d75[:,1]
l0500_d50_xicomp_cnfw = (l0500_d50[:,5]-l0500_d50[:,3])/l0500_d50[:,1]

l0500_d340_xicomp_shape = (l0500_d340[:,9]-l0500_d340[:,7])/l0500_d340[:,1]
l0500_d200_xicomp_shape = (l0500_d200[:,9]-l0500_d200[:,7])/l0500_d200[:,1]
l0500_d100_xicomp_shape = (l0500_d100[:,9]-l0500_d100[:,7])/l0500_d100[:,1]
l0500_d75_xicomp_shape = (l0500_d75[:,9]-l0500_d75[:,7])/l0500_d75[:,1]
l0500_d50_xicomp_shape = (l0500_d50[:,9]-l0500_d50[:,7])/l0500_d50[:,1]

l0500_d340_xicomp_spin = (l0500_d340[:,13]-l0500_d340[:,11])/l0500_d340[:,1]
l0500_d200_xicomp_spin = (l0500_d200[:,13]-l0500_d200[:,11])/l0500_d200[:,1]
l0500_d100_xicomp_spin = (l0500_d100[:,13]-l0500_d100[:,11])/l0500_d100[:,1]
l0500_d75_xicomp_spin = (l0500_d75[:,13]-l0500_d75[:,11])/l0500_d75[:,1]
l0500_d50_xicomp_spin = (l0500_d50[:,13]-l0500_d50[:,11])/l0500_d50[:,1]

l0250_d200= np.loadtxt('l0250_m7e11_d200b_nolog.dat')
l0250_d100= np.loadtxt('l0250_m8e11_d100b_nolog.dat')
l0250_d75=np.loadtxt('l0250_m9e11_d75b_nolog.dat')
l0250_d50=np.loadtxt('l0250_m1.5e12_d50b_nolog.dat')

l0250_d200_xicomp_cnfw = (l0250_d200[:,5]-l0250_d200[:,3])/l0250_d200[:,1]
l0250_d100_xicomp_cnfw = (l0250_d100[:,5]-l0250_d100[:,3])/l0250_d100[:,1]
l0250_d75_xicomp_cnfw = (l0250_d75[:,5]-l0250_d75[:,3])/l0250_d75[:,1]
l0250_d50_xicomp_cnfw = (l0250_d50[:,5]-l0250_d50[:,3])/l0250_d50[:,1]

l0250_d200_xicomp_shape = (l0250_d200[:,9]-l0250_d200[:,7])/l0250_d200[:,1]
l0250_d100_xicomp_shape = (l0250_d100[:,9]-l0250_d100[:,7])/l0250_d100[:,1]
l0250_d75_xicomp_shape = (l0250_d75[:,9]-l0250_d75[:,7])/l0250_d75[:,1]
l0250_d50_xicomp_shape = (l0250_d50[:,9]-l0250_d50[:,7])/l0250_d50[:,1]

l0250_d200_xicomp_spin = (l0250_d200[:,13]-l0250_d200[:,11])/l0250_d200[:,1]
l0250_d100_xicomp_spin = (l0250_d100[:,13]-l0250_d100[:,11])/l0250_d100[:,1]
l0250_d75_xicomp_spin = (l0250_d75[:,13]-l0250_d75[:,11])/l0250_d75[:,1]
l0250_d50_xicomp_spin = (l0250_d50[:,13]-l0250_d50[:,11])/l0250_d50[:,1]

l0125_d200= np.loadtxt('l0125_m7e10_d200b_nolog.dat')
l0125_d100= np.loadtxt('l0125_m8e10_d100b_nolog.dat')
l0125_d75=np.loadtxt('l0125_m9e10_d75b_nolog.dat')
l0125_d50=np.loadtxt('l0125_m1e11_d50b_nolog.dat')
l0125_d10=np.loadtxt('l0125_m2e11_d10b_nolog.dat')

l0125_d200_xicomp_cnfw = (l0125_d200[:,5]-l0125_d200[:,3])/l0125_d200[:,1]
l0125_d100_xicomp_cnfw = (l0125_d100[:,5]-l0125_d100[:,3])/l0125_d100[:,1]
l0125_d75_xicomp_cnfw = (l0125_d75[:,5]-l0125_d75[:,3])/l0125_d75[:,1]
l0125_d50_xicomp_cnfw = (l0125_d50[:,5]-l0125_d50[:,3])/l0125_d50[:,1]
l0125_d10_xicomp_cnfw = (l0125_d10[:,5]-l0125_d10[:,3])/l0125_d10[:,1]

l0125_d200_xicomp_shape = (l0125_d200[:,9]-l0125_d200[:,7])/l0125_d200[:,1]
l0125_d100_xicomp_shape = (l0125_d100[:,9]-l0125_d100[:,7])/l0125_d100[:,1]
l0125_d75_xicomp_shape = (l0125_d75[:,9]-l0125_d75[:,7])/l0125_d75[:,1]
l0125_d50_xicomp_shape = (l0125_d50[:,9]-l0125_d50[:,7])/l0125_d50[:,1]
l0125_d10_xicomp_shape = (l0125_d10[:,9]-l0125_d10[:,7])/l0125_d10[:,1]

l0125_d200_xicomp_spin = (l0125_d200[:,13]-l0125_d200[:,11])/l0125_d200[:,1]
l0125_d100_xicomp_spin = (l0125_d100[:,13]-l0125_d100[:,11])/l0125_d100[:,1]
l0125_d75_xicomp_spin = (l0125_d75[:,13]-l0125_d75[:,11])/l0125_d75[:,1]
l0125_d50_xicomp_spin = (l0125_d50[:,13]-l0125_d50[:,11])/l0125_d50[:,1]
l0125_d10_xicomp_spin = (l0125_d10[:,13]-l0125_d10[:,11])/l0125_d10[:,1]

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)
matplotlib.rcParams['lines.linewidth'] = 3

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125_d200[:,0], l0125_d200_xicomp_cnfw, 'b-') 
#             label=r'$\Delta = 200, \geq 7 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d100[:,0], l0125_d100_xicomp_cnfw, 'r-') 
#         label=r'$\Delta = 100, \geq 8 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d75[:,0], l0125_d75_xicomp_cnfw, 'g-') 
#         label=r'$\Delta = 75, \geq 9 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d50[:,0], l0125_d50_xicomp_cnfw, 'c-') 
#         label=r'$\Delta = 50, \geq 1 \times 10^{11}h^{-1}M_{\odot}$')
ax1.plot(l0125_d10[:,0], l0125_d10_xicomp_cnfw, color='darkgoldenrod', linestyle='-')
#         label=r'$\Delta = 10, \geq 2 \times 10^{11}h^{-1}M_{\odot}$')
ax1.set_xlim(4,18)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(handles=[],loc='lower right', title='L0125',numpoints=1, prop={'size': 13})

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250_d200[:,0], l0250_d200_xicomp_cnfw, 'b-') 
#             label=r'$\geq 7 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d100[:,0], l0250_d100_xicomp_cnfw, 'r-') 
#         label=r'$\geq 8 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d75[:,0], l0250_d75_xicomp_cnfw, 'g-') 
#         label=r'$\geq 9 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d50[:,0], l0250_d50_xicomp_cnfw, 'c-') 
#         label=r'$\geq 1.5 \times 10^{12}h^{-1}M_{\odot}$')
ax2.set_xlim(4,18)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(handles=[],loc='lower right', title='L0250', numpoints=1, prop={'size': 13})

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500_d340[:,0], l0500_d340_xicomp_cnfw, 'm-',
            label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200_xicomp_cnfw, 'b-', 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100_xicomp_cnfw, 'r-', 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75_xicomp_cnfw, 'g-', 
         label=r'$\Delta=75$')
ax3.plot(l0500_d50[:,0], l0500_d50_xicomp_cnfw, 'c-', 
         label=r'$\Delta=50$')
ax3.plot(l0500_d50[0,0], l0500_d50_xicomp_cnfw[0], color='darkgoldenrod', alpha=1.0,
         label=r'$\Delta=10$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.9,0.02)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='lower right', title='L0500', numpoints=1, prop={'size': 13})
#ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}} ) / \xi_{\mathrm{all}}$')
#ax3.set_title('L0250')

fig.tight_layout(pad=0.01)
plt.savefig('./FIGS/all_cfcompare_cnfw.'+fmttag)
#plt.close(fig)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125_d200[:,0], l0125_d200_xicomp_shape, 'b-') 
#             label=r'$\Delta = 200, \geq 7 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d100[:,0], l0125_d100_xicomp_shape, 'r-')
#         label=r'$\Delta = 100, \geq 8 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d75[:,0], l0125_d75_xicomp_shape, 'g-') 
#         label=r'$\Delta = 75, \geq 9 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d50[:,0], l0125_d50_xicomp_shape, 'c-') 
#         label=r'$\Delta = 50, \geq 1 \times 10^{11}h^{-1}M_{\odot}$')
ax1.plot(l0125_d10[:,0], l0125_d10_xicomp_shape, color='darkgoldenrod', linestyle='-')
#         label=r'$\Delta = 10, \geq 2 \times 10^{11}h^{-1}M_{\odot}$')
ax1.set_xlim(4,18)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(handles=[],loc='lower right', title='L0125',numpoints=1, prop={'size': 13})

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250_d200[:,0], l0250_d200_xicomp_shape, 'b-') 
#             label=r'$\geq 7 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d100[:,0], l0250_d100_xicomp_shape, 'r-') 
#         label=r'$\geq 8 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d75[:,0], l0250_d75_xicomp_shape, 'g-') 
#         label=r'$\geq 9 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d50[:,0], l0250_d50_xicomp_shape, 'c-') 
#         label=r'$\geq 1.5 \times 10^{12}h^{-1}M_{\odot}$')
ax2.set_xlim(4,18)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(handles=[],loc='lower right', title='L0250', numpoints=1, prop={'size': 13})

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500_d340[:,0], l0500_d340_xicomp_shape, 'm-',
            label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200_xicomp_shape, 'b-', 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100_xicomp_shape, 'r-', 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75_xicomp_shape, 'g-', 
         label=r'$\Delta=75$')
ax3.plot(l0500_d50[:,0], l0500_d50_xicomp_shape, 'c-', 
         label=r'$\Delta=50$')
ax3.plot(l0500_d50[0,0], l0500_d50_xicomp_shape[0], color='darkgoldenrod',
         label=r'$\Delta=10$')
ax3.set_xlim(4,18)
#ax3.set_ylim(-0.9,0.02)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='upper right', title='L0500', numpoints=1, prop={'size': 13})
#ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}} ) / \xi_{\mathrm{all}}$')
#ax3.set_title('L0250')

fig.tight_layout(pad=0.01)
plt.savefig('./FIGS/all_cfcompare_shape.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125_d200[:,0], l0125_d200_xicomp_spin, 'b-') 
#             label=r'$\Delta = 200, \geq 7 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d100[:,0], l0125_d100_xicomp_spin, 'r-') 
#         label=r'$\Delta = 100, \geq 8 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d75[:,0], l0125_d75_xicomp_spin, 'g-') 
#         label=r'$\Delta = 75, \geq 9 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d50[:,0], l0125_d50_xicomp_spin, 'c-') 
#         label=r'$\Delta = 50, \geq 1 \times 10^{11}h^{-1}M_{\odot}$')
ax1.plot(l0125_d10[:,0], l0125_d10_xicomp_spin, color='darkgoldenrod', linestyle='-')
#         label=r'$\Delta = 10, \geq 2 \times 10^{11}h^{-1}M_{\odot}$')
ax1.set_xlim(4,18)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(handles=[],loc='lower right', title='L0125',numpoints=1, prop={'size': 13})

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250_d200[:,0], l0250_d200_xicomp_spin, 'b-') 
#             label=r'$\geq 7 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d100[:,0], l0250_d100_xicomp_spin, 'r-') 
#         label=r'$\geq 8 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d75[:,0], l0250_d75_xicomp_spin, 'g-') 
#         label=r'$\geq 9 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d50[:,0], l0250_d50_xicomp_spin, 'c-') 
#         label=r'$\geq 1.5 \times 10^{12}h^{-1}M_{\odot}$')
ax2.set_xlim(4,18)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(handles=[],loc='lower right', title='L0250', numpoints=1, prop={'size': 13})

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500_d340[:,0], l0500_d340_xicomp_spin, 'm-',
            label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200_xicomp_spin, 'b-', 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100_xicomp_spin, 'r-', 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75_xicomp_spin, 'g-', 
         label=r'$\Delta=75$')
ax3.plot(l0500_d50[:,0], l0500_d50_xicomp_spin, 'c-', 
         label=r'$\Delta=50$')
ax3.plot(l0500_d50[0,0], l0500_d50_xicomp_spin[0], color='darkgoldenrod',
        label=r'$\Delta=10$')
ax3.set_xlim(4,18)
#ax3.set_ylim(-0.9,0.02)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='upper right', title='L0500', numpoints=1, prop={'size': 13})
#ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}} ) / \xi_{\mathrm{all}}$')
#ax3.set_title('L0250')

fig.tight_layout(pad=0.01)
plt.savefig('./FIGS/all_cfcompare_spin.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,16], l0125_d200[:,17], facecolor='b', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,16], l0125_d100[:,17], facecolor='r', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,16], l0125_d75[:,17], facecolor='c', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,16], l0125_d50[:,17], facecolor='g', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d10[:,0], l0125_d10[:,16], l0125_d10[:,17], facecolor='darkgoldenrod', edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d200[:,0], l0125_d200[:,15], 'b-') 
#             label=r'$\Delta = 200, \geq 7 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d100[:,0], l0125_d100[:,15], 'r-') 
#             label=r'$\Delta = 100, \geq 8 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d75[:,0], l0125_d75[:,15], 'c-') 
#             label=r'$\Delta = 75, \geq 9 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d50[:,0], l0125_d50[:,15], 'g-') 
#             label=r'$\Delta = 50, \geq 1 \times 10^{11}h^{-1}M_{\odot}$')
ax1.plot(l0125_d10[:,0], l0125_d10[:,15], color='darkgoldenrod', linestyle='-')
#         label=r'$\Delta = 10, \geq 2 \times 10^{11}h^{-1}M_{\odot}$')
ax1.legend(handles=[], loc='upper right', numpoints=1, title='L0125', prop={'size': 13})
ax1.set_xlim(4,18)
ax1.set_ylim(-0.5,2.5)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,16], l0250_d200[:,17], facecolor='b', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,16], l0250_d100[:,17], facecolor='r', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,16], l0250_d75[:,17], facecolor='c', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,16], l0250_d50[:,17], facecolor='g', edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d200[:,0], l0250_d200[:,15], 'b-') 
#             label=r'$\geq 7 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d100[:,0], l0250_d100[:,15], 'r-') 
#             label=r'$\geq 8 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d75[:,0], l0250_d75[:,15], 'c-') 
#             label=r'$\geq 9 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d50[:,0], l0250_d50[:,15], 'g-') 
#             label=r'$\geq 1.5 \times 10^{12}h^{-1}M_{\odot}$')
ax2.legend(handles=[], loc='upper right', numpoints=1, title='L0250', prop={'size': 13})
ax2.set_xlim(4,18)
ax2.set_ylim(-1, 1.5)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,16], l0500_d340[:,17], facecolor='m', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,16], l0500_d200[:,17], facecolor='b', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,16], l0500_d100[:,17], facecolor='r', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,16], l0500_d75[:,17], facecolor='c', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,16], l0500_d50[:,17], facecolor='g', edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,15], 'm-',
            label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,15], 'b-', 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,15], 'r-', 
             label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,15], 'c-', 
             label=r'$\Delta=75$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,15], 'g-', 
             label=r'$\Delta=50$')
ax3.plot(l0500_d50[0,0], l0500_d50[0,15], color='darkgoldenrod',
        label=r'$\Delta=10$')
ax3.legend(loc='lower right', numpoints=1, title='L0500', prop={'size': 13})
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-2, 0.5)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_cV.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,19], l0125_d200[:,20], facecolor='b', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,19], l0125_d100[:,20], facecolor='r', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,19], l0125_d75[:,20], facecolor='c', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,19], l0125_d50[:,20], facecolor='g', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d10[:,0], l0125_d10[:,19], l0125_d10[:,20], facecolor='darkgoldenrod', edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d200[:,0], l0125_d200[:,18], 'b-') 
#             label=r'$\Delta = 200, \geq 7 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d100[:,0], l0125_d100[:,18], 'r-') 
#             label=r'$\Delta = 100, \geq 8 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d75[:,0], l0125_d75[:,18], 'c-') 
#             label=r'$\Delta = 75, \geq 9 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d50[:,0], l0125_d50[:,18], 'g-') 
#             label=r'$\Delta = 50, \geq 1 \times 10^{11}h^{-1}M_{\odot}$')
ax1.plot(l0125_d10[:,0], l0125_d10[:,18], color='darkgoldenrod', linestyle='-') 
#             label=r'$\Delta = 10, \geq 2 \times 10^{11}h^{-1}M_{\odot}$')
ax1.legend(handles=[], loc='upper right', numpoints=1, title='L0125', prop={'size': 13})
ax1.set_xlim(4,18)
ax1.set_ylim(-0.1,0.6)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,19], l0250_d200[:,20], facecolor='b', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,19], l0250_d100[:,20], facecolor='r', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,19], l0250_d75[:,20], facecolor='c', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,19], l0250_d50[:,20], facecolor='g', edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d200[:,0], l0250_d200[:,18], 'b-') 
#             label=r'$\geq 7 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d100[:,0], l0250_d100[:,18], 'r-') 
#             label=r'$\geq 8 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d75[:,0], l0250_d75[:,18], 'c-') 
#             label=r'$\geq 9 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d50[:,0], l0250_d50[:,18], 'g-') 
#             label=r'$\geq 1.5 \times 10^{12}h^{-1}M_{\odot}$')
ax2.legend(handles=[],loc='upper right', numpoints=1, title='L0250', prop={'size': 13})
ax2.set_xlim(4,18)
ax2.set_ylim(-0.2, 0.3)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,19], l0500_d340[:,20], facecolor='m', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,19], l0500_d200[:,20], facecolor='b', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,19], l0500_d100[:,20], facecolor='r', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,19], l0500_d75[:,20], facecolor='c', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,19], l0500_d50[:,20], facecolor='g', edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,18], 'm-', 
             label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,18], 'b-', 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,18], 'r-', 
             label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,18], 'c-', 
             label=r'$\Delta=75$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,18], 'g-', 
             label=r'$\Delta=50$')
ax3.plot(l0500_d50[0,0], l0500_d50[0,18], color='darkgoldenrod',
         label=r'$\Delta=10$')
ax3.legend(loc='lower right', numpoints=1, title='L0500', prop={'size': 13})
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.5,0.1)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_cNFW.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,22], l0125_d200[:,23], facecolor='b', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,22], l0125_d100[:,23], facecolor='r', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,22], l0125_d75[:,23], facecolor='c', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,22], l0125_d50[:,23], facecolor='g', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d10[:,0], l0125_d10[:,22], l0125_d10[:,23], facecolor='darkgoldenrod', edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d200[:,0], l0125_d200[:,21], 'b-') 
#             label=r'$\Delta = 200, \geq 7 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d100[:,0], l0125_d100[:,21], 'r-') 
#             label=r'$\Delta = 100, \geq 8 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d75[:,0], l0125_d75[:,21], 'c-') 
#             label=r'$\Delta = 75, \geq 9 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d50[:,0], l0125_d50[:,21], 'g-') 
#             label=r'$\Delta = 50, \geq 1 \times 10^{11}h^{-1}M_{\odot}$')
ax1.plot(l0125_d10[:,0], l0125_d10[:,21], color='darkgoldenrod', linestyle='-') 
#             label=r'$\Delta = 10, \geq 2 \times 10^{11}h^{-1}M_{\odot}$')

ax1.legend(handles=[],loc='upper right', numpoints=1, title='L0125', prop={'size': 13})
ax1.set_xlim(4,18)
ax1.set_ylim(-0.1,1)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,22], l0250_d200[:,23], facecolor='b', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,22], l0250_d100[:,23], facecolor='r', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,22], l0250_d75[:,23], facecolor='c', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,22], l0250_d50[:,23], facecolor='g', edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d200[:,0], l0250_d200[:,21], 'b-') 
#             label=r'$\geq 7 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d100[:,0], l0250_d100[:,21], 'r-') 
#             label=r'$\geq 8 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d75[:,0], l0250_d75[:,21], 'c-') 
#             label=r'$\geq 9 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d50[:,0], l0250_d50[:,21], 'g-') 
#             label=r'$\geq 1.5 \times 10^{12}h^{-1}M_{\odot}$')
ax2.legend(handles=[], loc='upper right', numpoints=1, title='L0250', prop={'size': 13})
ax2.set_xlim(4,18)
ax2.set_ylim(-0.3,1.5)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,22], l0500_d340[:,23], facecolor='m', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,22], l0500_d200[:,23], facecolor='b', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,22], l0500_d100[:,23], facecolor='r', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,22], l0500_d75[:,23], facecolor='c', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,22], l0500_d50[:,23], facecolor='g', edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,21], 'm-', 
             label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,21], 'b-', 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,21], 'r-', 
             label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,21], 'c-', 
             label=r'$\Delta=75$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,21], 'g-', 
             label=r'$\Delta=50$')
ax3.plot(l0500_d50[0,0], l0500_d50[0,21], color='darkgoldenrod',
        label=r'$\Delta=10$')
ax3.legend(loc='upper right', numpoints=1, title='L0500', prop={'size': 13})
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.3, 2.5)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_shape.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,25], l0125_d200[:,26], facecolor='b', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,25], l0125_d100[:,26], facecolor='r', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,25], l0125_d75[:,26], facecolor='c', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,25], l0125_d50[:,26], facecolor='g', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d10[:,0], l0125_d10[:,25], l0125_d10[:,26], facecolor='darkgoldenrod', edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d200[:,0], l0125_d200[:,24], 'b-') 
#             label=r'$\Delta = 200, \geq 7 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d100[:,0], l0125_d100[:,24], 'r-') 
#             label=r'$\Delta = 100, \geq 8 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d75[:,0], l0125_d75[:,24], 'c-') 
#             label=r'$\Delta = 75, \geq 9 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d50[:,0], l0125_d50[:,24], 'g-') 
#             label=r'$\Delta = 50, \geq 1 \times 10^{11}h^{-1}M_{\odot}$')
ax1.plot(l0125_d10[:,0], l0125_d10[:,24], color='darkgoldenrod', linestyle='-') 
#             label=r'$\Delta = 10, \geq 2 \times 10^{11}h^{-1}M_{\odot}$')
ax1.legend(handles=[],loc='upper right', numpoints=1, title='L0125', prop={'size': 13})
ax1.set_xlim(4,18)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_ylim(-0.03,0.08)
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,25], l0250_d200[:,26], facecolor='b', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,25], l0250_d100[:,26], facecolor='r', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,25], l0250_d75[:,26], facecolor='c', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,25], l0250_d50[:,26], facecolor='g', edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d200[:,0], l0250_d200[:,24], 'b-') 
#             label=r'$\geq 7 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d100[:,0], l0250_d100[:,24], 'r-') 
#             label=r'$\geq 8 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d75[:,0], l0250_d75[:,24], 'c-') 
#             label=r'$\geq 9 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d50[:,0], l0250_d50[:,24], 'g-') 
#             label=r'$\geq 1.5 \times 10^{12}h^{-1}M_{\odot}$')
ax2.legend(handles=[], loc='upper right', numpoints=1, title='L0250', prop={'size': 13})
ax2.set_xlim(4,18)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,25], l0500_d340[:,26], facecolor='m', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,25], l0500_d200[:,26], facecolor='b', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,25], l0500_d100[:,26], facecolor='r', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,25], l0500_d75[:,26], facecolor='c', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,25], l0500_d50[:,26], facecolor='g', edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,24], 'm-', 
             label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,24], 'b-', 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,24], 'r-', 
             label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,24], 'c-', 
             label=r'$\Delta=75$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,24], 'g-', 
             label=r'$\Delta=50$')
ax3.plot(l0500_d50[0,0], l0500_d50[0,24], color='darkgoldenrod',
         label=r'$\Delta=10$')
ax3.legend(loc='upper right', numpoints=1, title='L0500', prop={'size': 13})
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.1,0.4)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_spin.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,28], l0125_d200[:,29], facecolor='b', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,28], l0125_d100[:,29], facecolor='r', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,28], l0125_d75[:,29], facecolor='c', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,28], l0125_d50[:,29], facecolor='g', edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d10[:,0], l0125_d10[:,28], l0125_d10[:,29], facecolor='darkgoldenrod', edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d200[:,0], l0125_d200[:,27], 'b-') 
#             label=r'$\Delta = 200, \geq 7 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d100[:,0], l0125_d100[:,27], 'r-') 
#             label=r'$\Delta = 100, \geq 8 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d75[:,0], l0125_d75[:,27], 'c-') 
#             label=r'$\Delta = 75, \geq 9 \times 10^{10}h^{-1}M_{\odot}$')
ax1.plot(l0125_d50[:,0], l0125_d50[:,27], 'g-') 
#             label=r'$\Delta = 50, \geq 1 \times 10^{11}h^{-1}M_{\odot}$')
ax1.plot(l0125_d10[:,0], l0125_d10[:,27], color='darkgoldenrod', linestyle='-')
#             label=r'$\Delta = 10, \geq 2 \times 10^{11}h^{-1}M_{\odot}$')
ax1.legend(handles=[],loc='upper right', numpoints=1, title='L0125', prop={'size': 13})
ax1.set_xlim(4,18)
ax1.set_ylim(-0.2,0.4)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,28], l0250_d200[:,29], facecolor='b', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,28], l0250_d100[:,29], facecolor='r', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,28], l0250_d75[:,29], facecolor='c', edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,28], l0250_d50[:,29], facecolor='g', edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d200[:,0], l0250_d200[:,27], 'b-') 
#             label=r'$\geq 7 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d100[:,0], l0250_d100[:,27], 'r-') 
#             label=r'$\geq 8 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d75[:,0], l0250_d75[:,27], 'c-') 
#             label=r'$\geq 9 \times 10^{11}h^{-1}M_{\odot}$')
ax2.plot(l0250_d50[:,0], l0250_d50[:,27], 'g-') 
#             label=r'$\geq 1.5 \times 10^{12}h^{-1}M_{\odot}$')
ax2.legend(handles=[], loc='upper right', numpoints=1, title='L0250', prop={'size': 13})
ax2.set_xlim(4,18)
ax2.set_ylim(-0.1,0.4)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,28], l0500_d340[:,29], facecolor='m', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,28], l0500_d200[:,29], facecolor='b', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,28], l0500_d100[:,29], facecolor='r', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,28], l0500_d75[:,29], facecolor='c', edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,28], l0500_d50[:,29], facecolor='g', edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,27], 'm-', 
             label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,27], 'b-', 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,27], 'r-', 
             label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,27], 'c-', 
             label=r'$\Delta=75$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,27], 'g-', 
             label=r'$\Delta=50$')
ax3.plot(l0500_d50[0,0], l0500_d50[0,0], color='darkgoldenrod',
         label=r'$\Delta=10$')
ax3.legend(loc='upper right', numpoints=1, title='L0500', prop={'size': 13})
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.1,0.4)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_nsat.'+fmttag)
#plt.close(fig)
