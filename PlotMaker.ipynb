# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
colord340 = cm.Blues(0.5*(1.+(340.-50.)/(340.-50.)))
colord200 = cm.Blues(0.5*(1.+(200.-50.)/(340.-50.)))
colord100 = cm.Blues(0.5*(1.+(100.-50.)/(340.-50.)))
colord75 = cm.Blues(0.5*(1.+(75.-50.)/(340.-50.)))
colord50 = cm.Blues(0.5*(1.+(50.-50.)/(340.-50.)))

fmttag = 'pdf'

# %%
l0500_d340 = np.loadtxt('l0500_m3e12_d340b.dat')
l0500_d200 = np.loadtxt('l0500_m4e12_d200b.dat')
l0500_d100 = np.loadtxt('l0500_m5e12_d100b.dat')
l0500_d75  = np.loadtxt('l0500_m6e12_d75b.dat')
l0500_d60  = np.loadtxt('l0500_m7e12_d60b.dat')
l0500_d50  = np.loadtxt('l0500_m7e12_d50b.dat')
l0500_d10  = np.loadtxt('l0500_m9e12_d10b.dat')

l0500_d340s= np.loadtxt('l0500_m4e13_d340b.dat')
l0500_d200s= np.loadtxt('l0500_m4e13_d200b.dat')
l0500_d100s= np.loadtxt('l0500_m4e13_d100b.dat')
l0500_d75s = np.loadtxt('l0500_m4e13_d75b.dat')
l0500_d60s = np.loadtxt('l0500_m4e13_d60b.dat')
l0500_d50s = np.loadtxt('l0500_m4e13_d50b.dat')
l0500_d10s = np.loadtxt('l0500_m4e13_d10b.dat')

l0500_d340_xicomp_cnfw = (l0500_d340[:,5]-l0500_d340[:,3])/l0500_d340[:,1]
l0500_d200_xicomp_cnfw = (l0500_d200[:,5]-l0500_d200[:,3])/l0500_d200[:,1]
l0500_d100_xicomp_cnfw = (l0500_d100[:,5]-l0500_d100[:,3])/l0500_d100[:,1]
l0500_d75_xicomp_cnfw  = (l0500_d75[:,5]-l0500_d75[:,3])/l0500_d75[:,1]
l0500_d60_xicomp_cnfw  = (l0500_d60[:,5]-l0500_d60[:,3])/l0500_d60[:,1]
l0500_d50_xicomp_cnfw  = (l0500_d50[:,5]-l0500_d50[:,3])/l0500_d50[:,1]
l0500_d10_xicomp_cnfw  = (l0500_d10[:,5]-l0500_d10[:,3])/l0500_d10[:,1]

l0500_d340_xicomp_shape = (l0500_d340s[:,9]-l0500_d340s[:,7])/l0500_d340s[:,1]
l0500_d200_xicomp_shape = (l0500_d200s[:,9]-l0500_d200s[:,7])/l0500_d200s[:,1]
l0500_d100_xicomp_shape = (l0500_d100s[:,9]-l0500_d100s[:,7])/l0500_d100s[:,1]
l0500_d75_xicomp_shape  = (l0500_d75s[:,9]-l0500_d75s[:,7])/l0500_d75s[:,1]
l0500_d60_xicomp_shape  = (l0500_d60s[:,9]-l0500_d60s[:,7])/l0500_d60s[:,1]
l0500_d50_xicomp_shape  = (l0500_d50s[:,9]-l0500_d50s[:,7])/l0500_d50s[:,1]
l0500_d10_xicomp_shape  = (l0500_d10s[:,9]-l0500_d10s[:,7])/l0500_d10s[:,1]

l0500_d340_xicomp_spin = (l0500_d340[:,13]-l0500_d340[:,11])/l0500_d340[:,1]
l0500_d200_xicomp_spin = (l0500_d200[:,13]-l0500_d200[:,11])/l0500_d200[:,1]
l0500_d100_xicomp_spin = (l0500_d100[:,13]-l0500_d100[:,11])/l0500_d100[:,1]
l0500_d75_xicomp_spin  = (l0500_d75[:,13]-l0500_d75[:,11])/l0500_d75[:,1]
l0500_d60_xicomp_spin  = (l0500_d60[:,13]-l0500_d60[:,11])/l0500_d60[:,1]
l0500_d50_xicomp_spin  = (l0500_d50[:,13]-l0500_d50[:,11])/l0500_d50[:,1]
l0500_d10_xicomp_spin  = (l0500_d10[:,13]-l0500_d10[:,11])/l0500_d10[:,1]

l0250_d340 = np.loadtxt('l0250_m6e11_d340b.dat')
l0250_d200 = np.loadtxt('l0250_m7e11_d200b.dat')
l0250_d100 = np.loadtxt('l0250_m8e11_d100b.dat')
l0250_d75  = np.loadtxt('l0250_m9e11_d75b.dat')
l0250_d60  = np.loadtxt('l0250_m1e12_d60b.dat')
l0250_d50  = np.loadtxt('l0250_m1.5e12_d50b.dat')
l0250_d10  = np.loadtxt('l0250_m2e12_d10b.dat')

l0250_d340s=np.loadtxt('l0250_m8e12_d340b.dat')
l0250_d200s= np.loadtxt('l0250_m8e12_d200b.dat')
l0250_d100s= np.loadtxt('l0250_m8e12_d100b.dat')
l0250_d75s = np.loadtxt('l0250_m8e12_d75b.dat')
l0250_d60s = np.loadtxt('l0250_m8e12_d60b.dat')
l0250_d50s = np.loadtxt('l0250_m8e12_d50b.dat')
l0250_d10s = np.loadtxt('l0250_m8e12_d10b.dat')

l0250_d340_xicomp_cnfw = (l0250_d340[:,5]-l0250_d340[:,3])/l0250_d340[:,1]
l0250_d200_xicomp_cnfw = (l0250_d200[:,5]-l0250_d200[:,3])/l0250_d200[:,1]
l0250_d100_xicomp_cnfw = (l0250_d100[:,5]-l0250_d100[:,3])/l0250_d100[:,1]
l0250_d75_xicomp_cnfw = (l0250_d75[:,5]-l0250_d75[:,3])/l0250_d75[:,1]
l0250_d60_xicomp_cnfw = (l0250_d60[:,5]-l0250_d60[:,3])/l0250_d60[:,1]
l0250_d50_xicomp_cnfw = (l0250_d50[:,5]-l0250_d50[:,3])/l0250_d50[:,1]
l0250_d10_xicomp_cnfw = (l0250_d10[:,5]-l0250_d10[:,3])/l0250_d10[:,1]

l0250_d340_xicomp_shape = (l0250_d340s[:,9]-l0250_d340s[:,7])/l0250_d340s[:,1]
l0250_d200_xicomp_shape = (l0250_d200s[:,9]-l0250_d200s[:,7])/l0250_d200s[:,1]
l0250_d100_xicomp_shape = (l0250_d100s[:,9]-l0250_d100s[:,7])/l0250_d100s[:,1]
l0250_d75_xicomp_shape = (l0250_d75s[:,9]-l0250_d75s[:,7])/l0250_d75s[:,1]
l0250_d60_xicomp_shape = (l0250_d60s[:,9]-l0250_d60s[:,7])/l0250_d60s[:,1]
l0250_d50_xicomp_shape = (l0250_d50s[:,9]-l0250_d50s[:,7])/l0250_d50s[:,1]
l0250_d10_xicomp_shape = (l0250_d10s[:,9]-l0250_d10s[:,7])/l0250_d10s[:,1]

l0250_d340_xicomp_spin = (l0250_d340[:,13]-l0250_d340[:,11])/l0250_d340[:,1]
l0250_d200_xicomp_spin = (l0250_d200[:,13]-l0250_d200[:,11])/l0250_d200[:,1]
l0250_d100_xicomp_spin = (l0250_d100[:,13]-l0250_d100[:,11])/l0250_d100[:,1]
l0250_d75_xicomp_spin = (l0250_d75[:,13]-l0250_d75[:,11])/l0250_d75[:,1]
l0250_d60_xicomp_spin = (l0250_d60[:,13]-l0250_d60[:,11])/l0250_d60[:,1]
l0250_d50_xicomp_spin = (l0250_d50[:,13]-l0250_d50[:,11])/l0250_d50[:,1]
l0250_d10_xicomp_spin = (l0250_d10[:,13]-l0250_d10[:,11])/l0250_d10[:,1]

l0125_d340= np.loadtxt('l0125_m6e10_d340b.dat')
l0125_d200= np.loadtxt('l0125_m7e10_d200b.dat')
l0125_d100= np.loadtxt('l0125_m8e10_d100b.dat')
l0125_d75=np.loadtxt('l0125_m9e10_d75b.dat')
l0125_d60 = np.loadtxt('l0125_m1e11_d60b.dat')
l0125_d50=np.loadtxt('l0125_m1e11_d50b.dat')
l0125_d10=np.loadtxt('l0125_m3e11_d20b.dat')

l0125_d340s= np.loadtxt('l0125_m2e12_d340b.dat')
l0125_d200s= np.loadtxt('l0125_m2e12_d200b.dat')
l0125_d100s= np.loadtxt('l0125_m2e12_d100b.dat')
l0125_d75s=np.loadtxt('l0125_m2e12_d75b.dat')
l0125_d60s=np.loadtxt('l0125_m2e12_d60b.dat')
l0125_d50s=np.loadtxt('l0125_m2e12_d50b.dat')
l0125_d10s=np.loadtxt('l0125_m2e12_d10b.dat')

l0125_d340_xicomp_cnfw = (l0125_d340[:,5]-l0125_d340[:,3])/l0125_d340[:,1]
l0125_d200_xicomp_cnfw = (l0125_d200[:,5]-l0125_d200[:,3])/l0125_d200[:,1]
l0125_d100_xicomp_cnfw = (l0125_d100[:,5]-l0125_d100[:,3])/l0125_d100[:,1]
l0125_d75_xicomp_cnfw = (l0125_d75[:,5]-l0125_d75[:,3])/l0125_d75[:,1]
l0125_d60_xicomp_cnfw = (l0125_d60[:,5]-l0125_d60[:,3])/l0125_d60[:,1]
l0125_d50_xicomp_cnfw = (l0125_d50[:,5]-l0125_d50[:,3])/l0125_d50[:,1]
l0125_d10_xicomp_cnfw = (l0125_d10[:,5]-l0125_d10[:,3])/l0125_d10[:,1]

l0125_d340_xicomp_shape = (l0125_d340s[:,9]-l0125_d340s[:,7])/l0125_d340s[:,1]
l0125_d200_xicomp_shape = (l0125_d200s[:,9]-l0125_d200s[:,7])/l0125_d200s[:,1]
l0125_d100_xicomp_shape = (l0125_d100s[:,9]-l0125_d100s[:,7])/l0125_d100s[:,1]
l0125_d75_xicomp_shape = (l0125_d75s[:,9]-l0125_d75s[:,7])/l0125_d75s[:,1]
l0125_d60_xicomp_shape = (l0125_d60s[:,9]-l0125_d60s[:,7])/l0125_d60s[:,1]
l0125_d50_xicomp_shape = (l0125_d50s[:,9]-l0125_d50s[:,7])/l0125_d50s[:,1]
l0125_d10_xicomp_shape = (l0125_d10s[:,9]-l0125_d10s[:,7])/l0125_d10s[:,1]

l0125_d340_xicomp_spin = (l0125_d340[:,13]-l0125_d340[:,11])/l0125_d340[:,1]
l0125_d200_xicomp_spin = (l0125_d200[:,13]-l0125_d200[:,11])/l0125_d200[:,1]
l0125_d100_xicomp_spin = (l0125_d100[:,13]-l0125_d100[:,11])/l0125_d100[:,1]
l0125_d75_xicomp_spin = (l0125_d75[:,13]-l0125_d75[:,11])/l0125_d75[:,1]
l0125_d60_xicomp_spin = (l0125_d60[:,13]-l0125_d60[:,11])/l0125_d60[:,1]
l0125_d50_xicomp_spin = (l0125_d50[:,13]-l0125_d50[:,11])/l0125_d50[:,1]
l0125_d10_xicomp_spin = (l0125_d10[:,13]-l0125_d10[:,11])/l0125_d10[:,1]

# %%
# reading all the matched catalogs
l0500m_d340= np.loadtxt('l0500_m3e12_d340b_match.dat')
l0500m_d200= np.loadtxt('l0500_m4e12_d200b_match.dat')
l0500m_d100= np.loadtxt('l0500_m5e12_d100b_match.dat')
l0500m_d75=np.loadtxt('l0500_m6e12_d75b_match.dat')
l0500m_d60=np.loadtxt('l0500_m7e12_d60b_match.dat')
l0500m_d50=np.loadtxt('l0500_m7e12_d50b_match.dat')
l0500m_d10=np.loadtxt('l0500_m9e12_d10b_match.dat')

l0500m_d340s= np.loadtxt('l0500_m4e13_d340b_match.dat')
l0500m_d200s= np.loadtxt('l0500_m4e13_d200b_match.dat')
l0500m_d100s= np.loadtxt('l0500_m4e13_d100b_match.dat')
l0500m_d75s=np.loadtxt('l0500_m4e13_d75b_match.dat')
l0500m_d60s=np.loadtxt('l0500_m4e13_d60b_match.dat')
l0500m_d50s=np.loadtxt('l0500_m4e13_d50b_match.dat')
l0500m_d10s=np.loadtxt('l0500_m4e13_d10b_match.dat')

l0500m_d340_xicomp_cnfw = (l0500m_d340[:,5]-l0500m_d340[:,3])/l0500m_d340[:,1]
l0500m_d200_xicomp_cnfw = (l0500m_d200[:,5]-l0500m_d200[:,3])/l0500m_d200[:,1]
l0500m_d100_xicomp_cnfw = (l0500m_d100[:,5]-l0500m_d100[:,3])/l0500m_d100[:,1]
l0500m_d75_xicomp_cnfw = (l0500m_d75[:,5]-l0500m_d75[:,3])/l0500m_d75[:,1]
l0500m_d60_xicomp_cnfw = (l0500m_d60[:,5]-l0500m_d60[:,3])/l0500m_d60[:,1]
l0500m_d50_xicomp_cnfw = (l0500m_d50[:,5]-l0500m_d50[:,3])/l0500m_d50[:,1]
l0500m_d10_xicomp_cnfw = (l0500m_d10[:,5]-l0500m_d50[:,3])/l0500m_d10[:,1]

l0500m_d340_xicomp_shape = (l0500m_d340s[:,9]-l0500m_d340s[:,7])/l0500m_d340s[:,1]
l0500m_d200_xicomp_shape = (l0500m_d200s[:,9]-l0500m_d200s[:,7])/l0500m_d200s[:,1]
l0500m_d100_xicomp_shape = (l0500m_d100s[:,9]-l0500m_d100s[:,7])/l0500m_d100s[:,1]
l0500m_d75_xicomp_shape = (l0500m_d75s[:,9]-l0500m_d75s[:,7])/l0500m_d75s[:,1]
l0500m_d60_xicomp_shape = (l0500m_d60s[:,9]-l0500m_d60s[:,7])/l0500m_d60s[:,1]
l0500m_d50_xicomp_shape = (l0500m_d50s[:,9]-l0500m_d50s[:,7])/l0500m_d50s[:,1]
l0500m_d10_xicomp_shape = (l0500m_d10s[:,9]-l0500m_d10s[:,7])/l0500m_d10s[:,1]

l0500m_d340_xicomp_spin = (l0500m_d340[:,13]-l0500m_d340[:,11])/l0500m_d340[:,1]
l0500m_d200_xicomp_spin = (l0500m_d200[:,13]-l0500m_d200[:,11])/l0500m_d200[:,1]
l0500m_d100_xicomp_spin = (l0500m_d100[:,13]-l0500m_d100[:,11])/l0500m_d100[:,1]
l0500m_d75_xicomp_spin = (l0500m_d75[:,13]-l0500m_d75[:,11])/l0500m_d75[:,1]
l0500m_d60_xicomp_spin = (l0500m_d60[:,13]-l0500m_d60[:,11])/l0500m_d60[:,1]
l0500m_d50_xicomp_spin = (l0500m_d50[:,13]-l0500m_d50[:,11])/l0500m_d50[:,1]
l0500m_d10_xicomp_spin = (l0500m_d10[:,13]-l0500m_d10[:,11])/l0500m_d10[:,1]

l0250m_d340= np.loadtxt('l0250_m6e11_d340b_match.dat')
l0250m_d200= np.loadtxt('l0250_m7e11_d200b_match.dat')
l0250m_d100= np.loadtxt('l0250_m8e11_d100b_match.dat')
l0250m_d75=np.loadtxt('l0250_m9e11_d75b_match.dat')
l0250m_d60=np.loadtxt('l0250_m1e12_d60b_match.dat')
l0250m_d50=np.loadtxt('l0250_m1.5e12_d50b_match.dat')
l0250m_d10=np.loadtxt('l0250_m2e12_d10b_match.dat')

l0250m_d340s= np.loadtxt('l0250_m8e12_d340b_match.dat')
l0250m_d200s= np.loadtxt('l0250_m8e12_d200b_match.dat')
l0250m_d100s= np.loadtxt('l0250_m8e12_d100b_match.dat')
l0250m_d75s=np.loadtxt('l0250_m8e12_d75b_match.dat')
l0250m_d60s=np.loadtxt('l0250_m8e12_d60b_match.dat')
l0250m_d50s=np.loadtxt('l0250_m8e12_d50b_match.dat')
l0250m_d10s= np.loadtxt('l0250_m8e12_d10b_match.dat')

l0250m_d340_xicomp_cnfw = (l0250m_d340[:,5]-l0250m_d340[:,3])/l0250m_d340[:,1]
l0250m_d200_xicomp_cnfw = (l0250m_d200[:,5]-l0250m_d200[:,3])/l0250m_d200[:,1]
l0250m_d100_xicomp_cnfw = (l0250m_d100[:,5]-l0250m_d100[:,3])/l0250m_d100[:,1]
l0250m_d75_xicomp_cnfw = (l0250m_d75[:,5]-l0250m_d75[:,3])/l0250m_d75[:,1]
l0250m_d60_xicomp_cnfw = (l0250m_d60[:,5]-l0250m_d60[:,3])/l0250m_d60[:,1]
l0250m_d50_xicomp_cnfw = (l0250m_d50[:,5]-l0250m_d50[:,3])/l0250m_d50[:,1]
l0250m_d10_xicomp_cnfw = (l0250m_d10[:,5]-l0250m_d10[:,3])/l0250m_d10[:,1]

l0250m_d340_xicomp_shape = (l0250m_d340s[:,9]-l0250m_d340s[:,7])/l0250m_d340s[:,1]
l0250m_d200_xicomp_shape = (l0250m_d200s[:,9]-l0250m_d200s[:,7])/l0250m_d200s[:,1]
l0250m_d100_xicomp_shape = (l0250m_d100s[:,9]-l0250m_d100s[:,7])/l0250m_d100s[:,1]
l0250m_d75_xicomp_shape = (l0250m_d75s[:,9]-l0250m_d75s[:,7])/l0250m_d75s[:,1]
l0250m_d60_xicomp_shape = (l0250m_d60s[:,9]-l0250m_d60s[:,7])/l0250m_d60s[:,1]
l0250m_d50_xicomp_shape = (l0250m_d50s[:,9]-l0250m_d50s[:,7])/l0250m_d50s[:,1]
l0250m_d10_xicomp_shape = (l0250m_d10s[:,9]-l0250m_d10s[:,7])/l0250m_d10s[:,1]

l0250m_d340_xicomp_spin = (l0250m_d340[:,13]-l0250m_d340[:,11])/l0250m_d340[:,1]
l0250m_d200_xicomp_spin = (l0250m_d200[:,13]-l0250m_d200[:,11])/l0250m_d200[:,1]
l0250m_d100_xicomp_spin = (l0250m_d100[:,13]-l0250m_d100[:,11])/l0250m_d100[:,1]
l0250m_d75_xicomp_spin = (l0250m_d75[:,13]-l0250m_d75[:,11])/l0250m_d75[:,1]
l0250m_d60_xicomp_spin = (l0250m_d60[:,13]-l0250m_d60[:,11])/l0250m_d60[:,1]
l0250m_d50_xicomp_spin = (l0250m_d50[:,13]-l0250m_d50[:,11])/l0250m_d50[:,1]
l0250m_d10_xicomp_spin = (l0250m_d10[:,13]-l0250m_d10[:,11])/l0250m_d10[:,1]

l0125m_d340= np.loadtxt('l0125_m6e10_d340b_match.dat')
l0125m_d200= np.loadtxt('l0125_m7e10_d200b_match.dat')
l0125m_d100= np.loadtxt('l0125_m8e10_d100b_match.dat')
l0125m_d75=np.loadtxt('l0125_m9e10_d75b_match.dat')
l0125m_d60=np.loadtxt('l0125_m1e11_d60b_match.dat')
l0125m_d50=np.loadtxt('l0125_m1e11_d50b_match.dat')
l0125m_d10=np.loadtxt('l0125_m3e11_d20b_match.dat')

l0125m_d340s= np.loadtxt('l0125_m2e12_d340b_match.dat')
l0125m_d200s= np.loadtxt('l0125_m2e12_d200b_match.dat')
l0125m_d100s= np.loadtxt('l0125_m2e12_d100b_match.dat')
l0125m_d75s=np.loadtxt('l0125_m2e12_d75b_match.dat')
l0125m_d60s=np.loadtxt('l0125_m2e12_d60b_match.dat')
l0125m_d50s=np.loadtxt('l0125_m2e12_d50b_match.dat')
l0125m_d10s=np.loadtxt('l0125_m2e12_d10b_match.dat')

l0125m_d340_xicomp_cnfw = (l0125m_d340[:,5]-l0125m_d340[:,3])/l0125m_d340[:,1]
l0125m_d200_xicomp_cnfw = (l0125m_d200[:,5]-l0125m_d200[:,3])/l0125m_d200[:,1]
l0125m_d100_xicomp_cnfw = (l0125m_d100[:,5]-l0125m_d100[:,3])/l0125m_d100[:,1]
l0125m_d75_xicomp_cnfw = (l0125m_d75[:,5]-l0125m_d75[:,3])/l0125m_d75[:,1]
l0125m_d60_xicomp_cnfw = (l0125m_d60[:,5]-l0125m_d60[:,3])/l0125m_d60[:,1]
l0125m_d50_xicomp_cnfw = (l0125m_d50[:,5]-l0125m_d50[:,3])/l0125m_d50[:,1]
l0125m_d10_xicomp_cnfw = (l0125m_d10[:,5]-l0125m_d10[:,3])/l0125m_d10[:,1]

l0125m_d340_xicomp_shape = (l0125m_d340s[:,9]-l0125m_d340s[:,7])/l0125m_d340s[:,1]
l0125m_d200_xicomp_shape = (l0125m_d200s[:,9]-l0125m_d200s[:,7])/l0125m_d200s[:,1]
l0125m_d100_xicomp_shape = (l0125m_d100s[:,9]-l0125m_d100s[:,7])/l0125m_d100s[:,1]
l0125m_d75_xicomp_shape = (l0125m_d75s[:,9]-l0125m_d75s[:,7])/l0125m_d75s[:,1]
l0125m_d60_xicomp_shape = (l0125m_d60s[:,9]-l0125m_d60s[:,7])/l0125m_d60s[:,1]
l0125m_d50_xicomp_shape = (l0125m_d50s[:,9]-l0125m_d50s[:,7])/l0125m_d50s[:,1]
l0125m_d10_xicomp_shape = (l0125m_d10s[:,9]-l0125m_d10s[:,7])/l0125m_d10s[:,1]

l0125m_d340_xicomp_spin = (l0125m_d340[:,13]-l0125m_d340[:,11])/l0125m_d340[:,1]
l0125m_d200_xicomp_spin = (l0125m_d200[:,13]-l0125m_d200[:,11])/l0125m_d200[:,1]
l0125m_d100_xicomp_spin = (l0125m_d100[:,13]-l0125m_d100[:,11])/l0125m_d100[:,1]
l0125m_d75_xicomp_spin = (l0125m_d75[:,13]-l0125m_d75[:,11])/l0125m_d75[:,1]
l0125m_d60_xicomp_spin = (l0125m_d60[:,13]-l0125m_d60[:,11])/l0125m_d60[:,1]
l0125m_d50_xicomp_spin = (l0125m_d50[:,13]-l0125m_d50[:,11])/l0125m_d50[:,1]
l0125m_d10_xicomp_spin = (l0125m_d10[:,13]-l0125m_d10[:,11])/l0125m_d10[:,1]

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)
matplotlib.rcParams['lines.linewidth'] = 3

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125_d340[:,0], l0125_d340_xicomp_cnfw, color=colord340)
ax1.plot(l0125_d200[:,0], l0125_d200_xicomp_cnfw, color=colord200) 
ax1.plot(l0125_d100[:,0], l0125_d100_xicomp_cnfw, color=colord100) 
ax1.plot(l0125_d75[:,0], l0125_d75_xicomp_cnfw, color=colord75)
#ax1.plot(l0125_d60[:,0], l0125_d60_xicomp_cnfw, color=colord60)
ax1.plot(l0125_d50[:,0], l0125_d50_xicomp_cnfw, color=colord50) 
ax1.plot(l0125_d10[:,0], l0125_d10_xicomp_cnfw, 'r--',
         label=r'$\Delta=10, \mathrm{Matched}$')
ax1.set_xlim(4,18)
ax1.set_ylim(-1.2,2.1)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(loc='lower left', title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           numpoints=1, prop={'size': 11}, frameon=False)

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250_d340[:,0], l0250_d340_xicomp_cnfw, color=colord340)
ax2.plot(l0250_d200[:,0], l0250_d200_xicomp_cnfw, color=colord200) 
ax2.plot(l0250_d100[:,0], l0250_d100_xicomp_cnfw, color=colord100) 
ax2.plot(l0250_d75[:,0], l0250_d75_xicomp_cnfw, color=colord75) 
ax2.plot(l0250_d50[:,0], l0250_d50_xicomp_cnfw, color=colord50)
#ax2.plot(l0250_d10[:,0], l0250_d10_xicomp_cnfw, color=colord10)

ax2.plot(l0250_d60[:,0], l0250_d60_xicomp_cnfw, 'r--',
         label=r'$\Delta=60, \mathrm{Matched}$') 

ax2.set_xlim(4,18)
ax2.set_ylim(-1.2,2.1)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(loc='lower left', title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           numpoints=1, prop={'size': 11}, frameon=False)

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500_d340[:,0], l0500_d340_xicomp_cnfw, color=colord340,
            label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200_xicomp_cnfw, color=colord200, 
         label=r'$\Delta=200$')

ax3.plot(l0500_d100[:,0], l0500_d100_xicomp_cnfw, color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75_xicomp_cnfw, color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500_d60[:,0], l0500_d60_xicomp_cnfw, color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500_d50[:,0], l0500_d50_xicomp_cnfw, color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500_d10[:,0], l0500_d10_xicomp_cnfw, color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500_d200[:,0], l0500_d200_xicomp_cnfw, 'r--',
         label=r'$\Delta=200, \mathrm{Matched}$')

ax3.set_xlim(4,18)
ax3.set_ylim(-1.2,2.1)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='upper right', title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', numpoints=1, 
           ncol=2, prop={'size': 11}, frameon=False)

fig.tight_layout(pad=0.01)
plt.savefig('./FIGS/all_cfcompare_cnfw.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125_d340s[:,0], l0125_d340_xicomp_shape, color=colord340)
ax1.plot(l0125_d200s[:,0], l0125_d200_xicomp_shape, color=colord200) 
ax1.plot(l0125_d100s[:,0], l0125_d100_xicomp_shape, color=colord100)
ax1.plot(l0125_d75s[:,0], l0125_d75_xicomp_shape, color=colord75)
#ax1.plot(l0125_d60s[:,0], l0125_d60_xicomp_shape, color=colord60)
ax1.plot(l0125_d50s[:,0], l0125_d50_xicomp_shape, color=colord50) 
ax1.plot(l0125_d10s[:,0], l0125_d10_xicomp_shape, 'r--',
         label=r'$\Delta=10, \mathrm{Matched}$')

ax1.set_xlim(4,18)
ax1.set_ylim(0,1.4)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(loc='lower right', title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           numpoints=1, prop={'size': 13}, frameon=False)

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250_d340s[:,0], l0250_d340_xicomp_shape, color=colord340)
ax2.plot(l0250_d200s[:,0], l0250_d200_xicomp_shape, color=colord200) 
ax2.plot(l0250_d100s[:,0], l0250_d100_xicomp_shape, color=colord100) 
ax2.plot(l0250_d75s[:,0], l0250_d75_xicomp_shape, color=colord75)
ax2.plot(l0250_d50s[:,0], l0250_d50_xicomp_shape, color=colord50)
ax2.plot(l0250_d60s[:,0], l0250_d60_xicomp_shape, 'r--',
        label=r'$\Delta=60, \mathrm{Matched}$')
#ax2.plot(l0250_d10s[:,0], l0250_d10_xicomp_shape, color=colord10)
ax2.set_xlim(4,18)
ax2.set_ylim(0,1.4)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(loc='lower right', title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           numpoints=1, prop={'size': 13}, frameon=False)

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500_d340s[:,0], l0500_d340_xicomp_shape, color=colord340,
            label=r'$\Delta=340$')
ax3.plot(l0500_d200s[:,0], l0500_d200_xicomp_shape, color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500_d100s[:,0], l0500_d100_xicomp_shape, color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75s[:,0], l0500_d75_xicomp_shape, color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500_d60s[:,0], l0500_d60_xicomp_shape, color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500_d50s[:,0], l0500_d50_xicomp_shape, color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500_d10s[:,0], l0500_d10_xicomp_shape, color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500_d200s[:,0], l0500_d200_xicomp_shape, 'r--', 
         label=r'$\Delta=200, \mathrm{Matched}$')
ax3.set_xlim(4,18)
ax3.set_ylim(0,1.4)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='lower left', title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', numpoints=1, 
           ncol=2, prop={'size': 13}, frameon=False)

fig.tight_layout(pad=0.01)
plt.savefig('./FIGS/all_cfcompare_shape.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125_d340[:,0], l0125_d340_xicomp_spin, color=colord340)
ax1.plot(l0125_d200[:,0], l0125_d200_xicomp_spin, color=colord200) 
ax1.plot(l0125_d100[:,0], l0125_d100_xicomp_spin, color=colord100) 
ax1.plot(l0125_d75[:,0], l0125_d75_xicomp_spin, color=colord75) 
#ax1.plot(l0125_d60[:,0], l0125_d60_xicomp_spin, color=colord60)
ax1.plot(l0125_d50[:,0], l0125_d50_xicomp_spin, color=colord50) 
ax1.plot(l0125_d10[:,0], l0125_d10_xicomp_spin, 'r--',
         label=r'$\Delta=10, \mathrm{Matched}$')
ax1.set_xlim(4,18)
ax1.set_ylim(0,1.4)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(loc='upper left', title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           numpoints=1, prop={'size': 13}, frameon=False)

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250_d340[:,0], l0250_d340_xicomp_spin, color=colord340)
ax2.plot(l0250_d200[:,0], l0250_d200_xicomp_spin, color=colord200) 
ax2.plot(l0250_d100[:,0], l0250_d100_xicomp_spin, color=colord100) 
ax2.plot(l0250_d75[:,0], l0250_d75_xicomp_spin, color=colord75) 
ax2.plot(l0250_d50[:,0], l0250_d50_xicomp_spin, color=colord50) 
#ax2.plot(l0250_d10[:,0], l0250_d10_xicomp_spin, color=colord10)
ax2.plot(l0250_d60[:,0], l0250_d60_xicomp_spin, 'r--',
         label=r'$\Delta=60, \mathrm{Matched}$')
ax2.set_xlim(4,18)
ax2.set_ylim(0,1.4)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(loc='lower right', title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           numpoints=1, prop={'size': 13}, frameon=False)

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500_d340[:,0], l0500_d340_xicomp_spin, color=colord340,
            label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200_xicomp_spin, color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100_xicomp_spin, color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75_xicomp_spin, color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500_d60[:,0], l0500_d60_xicomp_spin, color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500_d50[:,0], l0500_d50_xicomp_spin, color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500_d10[:,0], l0500_d10_xicomp_spin, color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500_d200[:,0], l0500_d200_xicomp_spin, 'r--', 
         label=r'$\Delta=200, \rm{Matched}$')
ax3.set_xlim(4,18)
ax3.set_ylim(0,1.4)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='lower right', title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', numpoints=1, 
           ncol=2, prop={'size': 13}, frameon=False)

fig.tight_layout(pad=0.01)
plt.savefig('./FIGS/all_cfcompare_spin.'+fmttag)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d340[:,0], l0125_d340[:,16], l0125_d340[:,17], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,16], l0125_d200[:,17], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,16], l0125_d100[:,17], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,16], l0125_d75[:,17], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d60[:,0], l0125_d60[:,16], l0125_d60[:,17], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,16], l0125_d50[:,17], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d10[:,0], l0125_d10[:,16], l0125_d10[:,17], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d340[:,0], l0125_d340[:,15], color=colord340)
ax1.plot(l0125_d200[:,0], l0125_d200[:,15], color=colord200) 
ax1.plot(l0125_d100[:,0], l0125_d100[:,15], color=colord100) 
ax1.plot(l0125_d75[:,0], l0125_d75[:,15], color=colord75)
#ax1.plot(l0125_d60[:,0], l0125_d60[:,15], color=colord60)
ax1.plot(l0125_d50[:,0], l0125_d50[:,15], color=colord50) 
ax1.plot(l0125_d10[:,0], l0125_d10[:,15], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')
ax1.legend(loc='lower right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_ylim(-0.2,1.5)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_ylim(-2,1.2)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d340[:,0], l0250_d340[:,16], l0250_d340[:,17], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,16], l0250_d200[:,17], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,16], l0250_d100[:,17], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,16], l0250_d75[:,17], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d60[:,0], l0250_d60[:,16], l0250_d60[:,17], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,16], l0250_d50[:,17], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d10[:,0], l0250_d10[:,16], l0250_d10[:,17], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d340[:,0], l0250_d340[:,15], color=colord340)
ax2.plot(l0250_d200[:,0], l0250_d200[:,15], color=colord200) 
ax2.plot(l0250_d100[:,0], l0250_d100[:,15], color=colord100) 
ax2.plot(l0250_d75[:,0], l0250_d75[:,15], color=colord75) 
ax2.plot(l0250_d50[:,0], l0250_d50[:,15], color=colord50) 
#ax2.plot(l0250_d10[:,0], l0250_d10[:,15], color=colord10)
ax2.plot(l0250_d60[:,0], l0250_d60[:,15], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$') 

ax2.legend(loc='lower right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_ylim(-2., 1.5)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,16], l0500_d340[:,17], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,16], l0500_d200[:,17], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,16], l0500_d100[:,17], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,16], l0500_d75[:,17], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d60[:,0], l0500_d60[:,16], l0500_d60[:,17], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,16], l0500_d50[:,17], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d10[:,0], l0500_d10[:,16], l0500_d10[:,17], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,15], color=colord340,
            label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,15], color=colord200, 
             label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,15], color=colord100, 
             label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,15], color=colord75, 
             label=r'$\Delta=75$')
#ax3.plot(l0500_d60[:,0], l0500_d60[:,15], color=colord60,
#        label=r'$\Delta=60$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,15], color=colord50, 
             label=r'$\Delta=50$')
#ax3.plot(l0500_d10[:,0], l0500_d10[:,15], color=colord10,
#        label=r'$\Delta=10$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,15], 'r--', 
             label=r'$\Delta=200,\mathrm{Matched}$')
ax3.legend(loc='upper right', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-2., 1.5)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_cV.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d340[:,0], l0125_d340[:,19], l0125_d340[:,20], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,19], l0125_d200[:,20], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,19], l0125_d100[:,20], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,19], l0125_d75[:,20], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d60[:,0], l0125_d60[:,19], l0125_d60[:,20], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,19], l0125_d50[:,20], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d10[:,0], l0125_d10[:,19], l0125_d10[:,20], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d340[:,0], l0125_d340[:,18], color=colord340)
ax1.plot(l0125_d200[:,0], l0125_d200[:,18], color=colord200) 
ax1.plot(l0125_d100[:,0], l0125_d100[:,18], color=colord100) 
ax1.plot(l0125_d75[:,0], l0125_d75[:,18], color=colord75) 
#ax1.plot(l0125_d60[:,0], l0125_d60[:,18], color=colord60)
ax1.plot(l0125_d50[:,0], l0125_d50[:,18], color=colord50) 
ax1.plot(l0125_d10[:,0], l0125_d10[:,18], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$') 

ax1.legend(loc='upper right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_ylim(-0.4,0.4)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d340[:,0], l0250_d340[:,19], l0250_d340[:,20], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,19], l0250_d200[:,20], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,19], l0250_d100[:,20], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,19], l0250_d75[:,20], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d60[:,0], l0250_d60[:,19], l0250_d60[:,20], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,19], l0250_d50[:,20], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d10[:,0], l0250_d10[:,19], l0250_d10[:,20], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d340[:,0], l0250_d340[:,18], color=colord340)
ax2.plot(l0250_d200[:,0], l0250_d200[:,18], color=colord200)
ax2.plot(l0250_d100[:,0], l0250_d100[:,18], color=colord100) 
ax2.plot(l0250_d75[:,0], l0250_d75[:,18], color=colord75) 
ax2.plot(l0250_d50[:,0], l0250_d50[:,18], color=colord50)
#ax2.plot(l0250_d10[:,0], l0250_d10[:,18], color=colord10)
ax2.plot(l0250_d60[:,0], l0250_d60[:,18], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='upper right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_ylim(-0.4, 0.4)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,19], l0500_d340[:,20], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,19], l0500_d200[:,20], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,19], l0500_d100[:,20], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,19], l0500_d75[:,20], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d60[:,0], l0500_d60[:,19], l0500_d60[:,20], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,19], l0500_d50[:,20], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d10[:,0], l0500_d10[:,19], l0500_d10[:,20], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,18], color=colord340, 
             label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,18], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,18],color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,18], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500_d60[:,0], l0500_d60[:,18], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,18], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500_d10[:,0], l0500_d10[:,18], color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,18], 'r--', 
         label=r'$\Delta=200,\mathrm{Matched}$')
ax3.legend(loc='upper right', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.4,0.4)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_cNFW.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d340s[:,0], l0125_d340s[:,22], l0125_d340s[:,23], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d200s[:,0], l0125_d200s[:,22], l0125_d200s[:,23], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100s[:,0], l0125_d100s[:,22], l0125_d100s[:,23], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75s[:,0], l0125_d75s[:,22], l0125_d75s[:,23], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d60s[:,0], l0125_d60s[:,22], l0125_d60s[:,23], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50s[:,0], l0125_d50s[:,22], l0125_d50s[:,23], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d10s[:,0], l0125_d10s[:,22], l0125_d10s[:,23], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d340s[:,0], l0125_d340s[:,21], color=colord340)
ax1.plot(l0125_d200s[:,0], l0125_d200s[:,21], color=colord200) 
ax1.plot(l0125_d100s[:,0], l0125_d100s[:,21], color=colord100) 
ax1.plot(l0125_d75s[:,0], l0125_d75s[:,21], color=colord75) 
#ax1.plot(l0125_d60s[:,0], l0125_d60s[:,21], color=colord60)
ax1.plot(l0125_d50s[:,0], l0125_d50s[:,21], color=colord50) 
ax1.plot(l0125_d10s[:,0], l0125_d10s[:,21], 'r--',
        label=r'$\Delta=10,\mathrm{Matched}$') 

ax1.legend(loc='upper right', numpoints=1, title=r'Low Mass ($\geq2\times10^{12}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_ylim(-0.1,1.2)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d340s[:,0], l0250_d340s[:,22], l0250_d340s[:,23], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d200s[:,0], l0250_d200s[:,22], l0250_d200s[:,23], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100s[:,0], l0250_d100s[:,22], l0250_d100s[:,23], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75s[:,0], l0250_d75s[:,22], l0250_d75s[:,23], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d60s[:,0], l0250_d60s[:,22], l0250_d60s[:,23], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50s[:,0], l0250_d50s[:,22], l0250_d50s[:,23], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d10s[:,0], l0250_d10s[:,22], l0250_d10s[:,23], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d340s[:,0], l0250_d340s[:,21], color=colord340)
ax2.plot(l0250_d200s[:,0], l0250_d200s[:,21], color=colord200) 
ax2.plot(l0250_d100s[:,0], l0250_d100s[:,21], color=colord100) 
ax2.plot(l0250_d75s[:,0], l0250_d75s[:,21], color=colord75)
#ax2.plot(l0250_d60s[:,0], l0250_d60s[:,21], color=colord60)
ax2.plot(l0250_d50s[:,0], l0250_d50s[:,21], color=colord50)
#ax2.plot(l0250_d10s[:,0], l0250_d10s[:,21], color=colord10)
ax2.plot(l0250_d60s[:,0], l0250_d60s[:,21], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='upper right', numpoints=1, title=r'Mid Mass ($\geq8\times10^{12}h^{-1}M_{\odot}$)',
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_ylim(-0.1,1.2)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340s[:,0], l0500_d340s[:,22], l0500_d340s[:,23], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200s[:,0], l0500_d200s[:,22], l0500_d200s[:,23], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100s[:,0], l0500_d100s[:,22], l0500_d100s[:,23], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75s[:,0], l0500_d75s[:,22], l0500_d75s[:,23], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d60s[:,0], l0500_d60s[:,22], l0500_d60s[:,23], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50s[:,0], l0500_d50s[:,22], l0500_d50s[:,23], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d10s[:,0], l0500_d10s[:,22], l0500_d10s[:,23], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340s[:,0], l0500_d340s[:,21], color=colord340, 
             label=r'$\Delta=340$')
ax3.plot(l0500_d200s[:,0], l0500_d200s[:,21], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500_d100s[:,0], l0500_d100s[:,21], color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75s[:,0], l0500_d75s[:,21], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500_d60s[:,0], l0500_d60s[:,21], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500_d50s[:,0], l0500_d50s[:,21], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500_d10s[:,0], l0500_d10s[:,21], color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500_d200s[:,0], l0500_d200s[:,21], 'r--', 
         label=r'$\Delta=200,\mathrm{Matched}$')
ax3.legend(loc='upper right', numpoints=1, title=r'High Mass ($\geq4\times10^{13}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.1, 1.2)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_shape.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d340[:,0], l0125_d340[:,25], l0125_d340[:,26], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,25], l0125_d200[:,26], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,25], l0125_d100[:,26], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,25], l0125_d75[:,26], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d60[:,0], l0125_d60[:,25], l0125_d60[:,26], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,25], l0125_d50[:,26], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d10[:,0], l0125_d10[:,25], l0125_d10[:,26], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d340[:,0], l0125_d340[:,24], color=colord340)
ax1.plot(l0125_d200[:,0], l0125_d200[:,24], color=colord200) 
ax1.plot(l0125_d100[:,0], l0125_d100[:,24], color=colord100) 
ax1.plot(l0125_d75[:,0], l0125_d75[:,24], color=colord75)
#ax1.plot(l0125_d60[:,0], l0125_d60[:,24], color=colord60)
ax1.plot(l0125_d50[:,0], l0125_d50[:,24], color=colord50) 
ax1.plot(l0125_d10[:,0], l0125_d10[:,24], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$') 
ax1.legend(loc='upper right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_ylim(-0.05,0.4)
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d340[:,0], l0250_d340[:,25], l0250_d340[:,26], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,25], l0250_d200[:,26], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,25], l0250_d100[:,26], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,25], l0250_d75[:,26], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d60[:,0], l0250_d60[:,25], l0250_d60[:,26], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,25], l0250_d50[:,26], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d10[:,0], l0250_d10[:,25], l0250_d10[:,26], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d340[:,0], l0250_d340[:,24], color=colord340)
ax2.plot(l0250_d200[:,0], l0250_d200[:,24], color=colord200) 
ax2.plot(l0250_d100[:,0], l0250_d100[:,24], color=colord100) 
ax2.plot(l0250_d75[:,0], l0250_d75[:,24], color=colord75) 
#ax2.plot(l0250_d60[:,0], l0250_d60[:,24], color=colord60)
ax2.plot(l0250_d50[:,0], l0250_d50[:,24], color=colord50)
#ax2.plot(l0250_d10[:,0], l0250_d10[:,24], color=colord10)
ax2.plot(l0250_d60[:,0], l0250_d60[:,24], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='upper right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_ylim(-0.05,0.4)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,25], l0500_d340[:,26], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,25], l0500_d200[:,26], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,25], l0500_d100[:,26], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,25], l0500_d75[:,26], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d60[:,0], l0500_d60[:,25], l0500_d60[:,26], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,25], l0500_d50[:,26], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d10[:,0], l0500_d50[:,25], l0500_d10[:,26], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,24], color=colord340, 
             label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,24], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,24], color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,24], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500_d60[:,0], l0500_d60[:,24], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,24], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500_d10[:,0], l0500_d10[:,24], color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,24], 'r--', 
         label=r'$\Delta=200,\mathrm{Matched}$')

ax3.legend(loc='upper right', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.05,0.4)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_spin.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}


matplotlib.rc('font', **font)

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125_d340[:,0], l0125_d340[:,28], l0125_d340[:,29], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d200[:,0], l0125_d200[:,28], l0125_d200[:,29], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d100[:,0], l0125_d100[:,28], l0125_d100[:,29], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d75[:,0], l0125_d75[:,28], l0125_d75[:,29], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d60[:,0], l0125_d60[:,28], l0125_d60[:,29], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125_d50[:,0], l0125_d50[:,28], l0125_d50[:,29], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125_d10[:,0], l0125_d10[:,28], l0125_d10[:,29], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125_d340[:,0], l0125_d340[:,27], color=colord340)
ax1.plot(l0125_d200[:,0], l0125_d200[:,27], color=colord200) 
ax1.plot(l0125_d100[:,0], l0125_d100[:,27], color=colord100) 
ax1.plot(l0125_d75[:,0], l0125_d75[:,27], color=colord75) 
#ax1.plot(l0125_d60[:,0], l0125_d60[:,27], color=colord60)
ax1.plot(l0125_d50[:,0], l0125_d50[:,27], color=colord50) 
ax1.plot(l0125_d10[:,0], l0125_d10[:,27], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')

ax1.legend(loc='upper right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_ylim(-0.05,0.4)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax1.set_xticklabels([])

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250_d340[:,0], l0250_d340[:,28], l0250_d340[:,29], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d200[:,0], l0250_d200[:,28], l0250_d200[:,29], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d100[:,0], l0250_d100[:,28], l0250_d100[:,29], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d75[:,0], l0250_d75[:,28], l0250_d75[:,29], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d60[:,0], l0250_d60[:,28], l0250_d60[:,29], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250_d50[:,0], l0250_d50[:,28], l0250_d50[:,29], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250_d10[:,0], l0250_d10[:,28], l0250_d10[:,29], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250_d340[:,0], l0250_d340[:,27], color=colord340)
ax2.plot(l0250_d200[:,0], l0250_d200[:,27], color=colord200) 
ax2.plot(l0250_d100[:,0], l0250_d100[:,27], color=colord100) 
ax2.plot(l0250_d75[:,0], l0250_d75[:,27], color=colord75) 
#ax2.plot(l0250_d60[:,0], l0250_d60[:,27], color=colord60)
ax2.plot(l0250_d50[:,0], l0250_d50[:,27], color=colord50)
#ax2.plot(l0250_d10[:,0], l0250_d10[:,27], color=colord10)
ax2.plot(l0250_d60[:,0], l0250_d60[:,27], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='upper right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)',
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_ylim(-0.05,0.4)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax2.set_xticklabels([])

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500_d340[:,0], l0500_d340[:,28], l0500_d340[:,29], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d200[:,0], l0500_d200[:,28], l0500_d200[:,29], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d100[:,0], l0500_d100[:,28], l0500_d100[:,29], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d75[:,0], l0500_d75[:,28], l0500_d75[:,29], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d60[:,0], l0500_d60[:,28], l0500_d60[:,29], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500_d50[:,0], l0500_d50[:,28], l0500_d50[:,29], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500_d10[:,0], l0500_d10[:,28], l0500_d10[:,29], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,27], color=colord340, 
             label=r'$\Delta=340$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,27], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500_d100[:,0], l0500_d100[:,27], color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500_d75[:,0], l0500_d75[:,27], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500_d60[:,0], l0500_d60[:,27], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500_d50[:,0], l0500_d50[:,27], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500_d10[:,0], l0500_d10[:,27], color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500_d200[:,0], l0500_d200[:,27], 'r--', 
         label=r'$\Delta=200,\mathrm{Matched}$')

ax3.legend(loc='upper right', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.05,0.5)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/all_mcf_nsat.'+fmttag)
#plt.close(fig)

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)
matplotlib.rcParams['lines.linewidth'] = 3

fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125m_d340[:,0], l0125m_d340_xicomp_cnfw, color=colord340)
ax1.plot(l0125m_d200[:,0], l0125m_d200_xicomp_cnfw, color=colord200) 
ax1.plot(l0125m_d100[:,0], l0125m_d100_xicomp_cnfw, color=colord100) 
ax1.plot(l0125m_d75[:,0], l0125m_d75_xicomp_cnfw, color=colord75) 
#ax1.plot(l0125m_d60[:,0], l0125m_d60_xicomp_cnfw, color=colord60)
ax1.plot(l0125m_d50[:,0], l0125m_d50_xicomp_cnfw, color=colord50) 
ax1.plot(l0125m_d10[:,0], l0125m_d10_xicomp_cnfw, 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')

ax1.set_xlim(4,18)
ax1.set_ylim(-1.,2.1)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(loc='lower right', title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           numpoints=1, prop={'size': 13}, frameon=False)

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250m_d340[:,0], l0250m_d340_xicomp_cnfw, color=colord340)
ax2.plot(l0250m_d200[:,0], l0250m_d200_xicomp_cnfw, color=colord200) 
ax2.plot(l0250m_d100[:,0], l0250m_d100_xicomp_cnfw, color=colord100) 
ax2.plot(l0250m_d75[:,0], l0250m_d75_xicomp_cnfw, color=colord75) 
#ax2.plot(l0250m_d60[:,0], l0250m_d60_xicomp_cnfw, color=colord60)
ax2.plot(l0250m_d50[:,0], l0250m_d50_xicomp_cnfw, color=colord50)
#ax2.plot(l0250m_d10[:,0], l0250m_d10_xicomp_cnfw, color=colord10)
ax2.plot(l0250m_d60[:,0], l0250m_d60_xicomp_cnfw, 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.set_xlim(4,18)
ax2.set_ylim(-1.,2.1)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(loc='upper right', title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           numpoints=1, prop={'size': 13}, frameon=False)

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500m_d340[:,0], l0500m_d340_xicomp_cnfw, color=colord340,
            label=r'$\Delta=340$')
ax3.plot(l0500m_d200[:,0], l0500m_d200_xicomp_cnfw, color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500m_d100[:,0], l0500m_d100_xicomp_cnfw, color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500m_d75[:,0], l0500m_d75_xicomp_cnfw, color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500m_d60[:,0], l0500m_d60_xicomp_cnfw, color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500m_d50[:,0], l0500m_d50_xicomp_cnfw, color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500m_d10[:,0], l0500m_d10_xicomp_cnfw, color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500m_d200[:,0], l0500m_d200_xicomp_cnfw, 'r--', 
         label=r'$\Delta=200,\mathrm{Matched}$')

ax3.set_xlim(4,18)
ax3.set_ylim(-1.,2.1)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='upper right', title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', numpoints=1, 
           ncol=2, prop={'size': 13}, frameon=False)
#ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}} ) / \xi_{\mathrm{all}}$')
#ax3.set_title('L0250')

fig.tight_layout(pad=0.01)
plt.savefig('./FIGS/match_cfcompare_cnfw.'+fmttag)

# %%
fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125m_d340s[:,0], l0125m_d340_xicomp_shape, color=colord340)
ax1.plot(l0125m_d200s[:,0], l0125m_d200_xicomp_shape, color=colord200) 
ax1.plot(l0125m_d100s[:,0], l0125m_d100_xicomp_shape, color=colord100)
ax1.plot(l0125m_d75s[:,0], l0125m_d75_xicomp_shape, color=colord75) 
#ax1.plot(l0125m_d60s[:,0], l0125m_d60_xicomp_shape, color=colord60)
ax1.plot(l0125m_d50s[:,0], l0125m_d50_xicomp_shape, color=colord50) 
ax1.plot(l0125m_d10s[:,0], l0125m_d10_xicomp_shape, 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')

ax1.set_xlim(4,18)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(loc='lower right', title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           numpoints=1, prop={'size': 13}, frameon=False)

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250m_d340s[:,0], l0250m_d340_xicomp_shape, color=colord340)
ax2.plot(l0250m_d200s[:,0], l0250m_d200_xicomp_shape, color=colord200) 
ax2.plot(l0250m_d100s[:,0], l0250m_d100_xicomp_shape, color=colord100) 
ax2.plot(l0250m_d75s[:,0], l0250m_d75_xicomp_shape, color=colord75) 
#ax2.plot(l0250m_d60s[:,0], l0250m_d60_xicomp_shape, color=colord60)
ax2.plot(l0250m_d50s[:,0], l0250m_d50_xicomp_shape, color=colord50)
#ax2.plot(l0250m_d10s[:,0], l0250m_d10_xicomp_shape, color=colord10)
ax2.plot(l0250m_d60s[:,0], l0250m_d60_xicomp_shape, 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.set_xlim(4,18)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(loc='lower right', title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           numpoints=1, prop={'size': 13}, frameon=False)

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500m_d340s[:,0], l0500_d340_xicomp_shape, color=colord340,
            label=r'$\Delta=340$')
ax3.plot(l0500m_d200s[:,0], l0500m_d200_xicomp_shape, color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500m_d100s[:,0], l0500m_d100_xicomp_shape, color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500m_d75s[:,0], l0500m_d75_xicomp_shape, color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500m_d60s[:,0], l0500m_d60_xicomp_shape, color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500m_d50s[:,0], l0500m_d50_xicomp_shape, color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500m_d10s[:,0], l0500m_d10_xicomp_shape, color=colord10,
#         label=r'$\Delta=10$')
ax3.plot(l0500m_d200s[:,0], l0500m_d200_xicomp_shape, 'r--', 
         label=r'$\Delta=200,\mathrm{Matched}$')

ax3.set_xlim(4,18)
#ax3.set_ylim(-0.9,0.02)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='upper right', title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, numpoints=1, prop={'size': 13}, frameon=False)
#ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}} ) / \xi_{\mathrm{all}}$')
#ax3.set_title('L0250')

fig.tight_layout(pad=0.01)
#plt.savefig('./FIGS/match_cfcompare_shape.'+fmttag)
#plt.close(fig)

# %%
fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.semilogx(l0125m_d340[:,0], l0125m_d340_xicomp_spin, color=colord340)
ax1.plot(l0125m_d200[:,0], l0125m_d200_xicomp_spin, color=colord200) 
ax1.plot(l0125m_d100[:,0], l0125m_d100_xicomp_spin, color=colord100) 
ax1.plot(l0125m_d75[:,0], l0125m_d75_xicomp_spin, color=colord75) 
#ax1.plot(l0125m_d60[:,0], l0125m_d60_xicomp_spin, color=colord60)
ax1.plot(l0125m_d50[:,0], l0125m_d50_xicomp_spin, color=colord50) 
ax1.plot(l0125m_d10[:,0], l0125m_d10_xicomp_spin, 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')
ax1.set_xlim(4,18)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_xticklabels([])
ax1.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax1.legend(loc='lower right', title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           numpoints=1, prop={'size': 13}, frameon=False)

ax2.axhline(y=0, color='k', linestyle='--')
ax2.semilogx(l0250m_d340[:,0], l0250m_d340_xicomp_spin, color=colord340)
ax2.plot(l0250m_d200[:,0], l0250m_d200_xicomp_spin, color=colord200) 
ax2.plot(l0250m_d100[:,0], l0250m_d100_xicomp_spin, color=colord100) 
ax2.plot(l0250m_d75[:,0], l0250m_d75_xicomp_spin, color=colord75) 
#ax2.plot(l0250m_d60[:,0], l0250m_d60_xicomp_spin, color=colord60)
ax2.plot(l0250m_d50[:,0], l0250m_d50_xicomp_spin, color=colord50) 
#ax2.plot(l0250m_d10[:,0], l0250m_d10_xicomp_spin, color=colord10)
ax2.plot(l0250m_d60[:,0], l0250m_d60_xicomp_spin, 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.set_xlim(4,18)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_xticklabels([])
ax2.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax2.legend(loc='lower right', title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)',
           numpoints=1, prop={'size': 13}, frameon=False)

ax3.axhline(y=0, color='k', linestyle='--')
ax3.semilogx(l0500m_d340[:,0], l0500m_d340_xicomp_spin, color=colord340,
            label=r'$\Delta=340$')
ax3.plot(l0500m_d200[:,0], l0500m_d200_xicomp_spin, color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500m_d100[:,0], l0500m_d100_xicomp_spin, color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500m_d75[:,0], l0500m_d75_xicomp_spin, color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500m_d60[:,0], l0500m_d60_xicomp_spin, color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500m_d50[:,0], l0500m_d50_xicomp_spin, color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500m_d10[:,0], l0500m_d10_xicomp_spin, color=colord10,
#        label=r'$\Delta=10$')
ax3.plot(l0500m_d200[:,0], l0500m_d200_xicomp_spin, 'r--', 
         label=r'$\Delta=200,\mathrm{Matched}$')

ax3.set_xlim(4,18)
#ax3.set_ylim(-0.9,0.02)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_xlabel(r'$r \ (h^{-1}\mathrm{Mpc})$')
ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}}) / \xi_{\mathrm{all}}$')
ax3.legend(loc='lower right', title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, numpoints=1, prop={'size': 13}, frameon=False)
#ax3.set_ylabel(r'$(\xi_{\mathrm{high}} - \xi_{\mathrm{low}} ) / \xi_{\mathrm{all}}$')
#ax3.set_title('L0250')

fig.tight_layout(pad=0.01)
plt.savefig('./FIGS/match_cfcompare_spin.'+fmttag)
#plt.close(fig)

# %%
fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125m_d340[:,0], l0125m_d340[:,16], l0125m_d340[:,17], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d200[:,0], l0125m_d200[:,16], l0125m_d200[:,17], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d100[:,0], l0125m_d100[:,16], l0125m_d100[:,17], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d75[:,0], l0125m_d75[:,16], l0125m_d75[:,17], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d60[:,0], l0125m_d60[:,16], l0125m_d60[:,17], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d50[:,0], l0125m_d50[:,16], l0125m_d50[:,17], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d10[:,0], l0125m_d10[:,16], l0125m_d10[:,17], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125m_d340[:,0], l0125m_d340[:,15], color=colord340)
ax1.plot(l0125m_d200[:,0], l0125m_d200[:,15], color=colord200) 
ax1.plot(l0125m_d100[:,0], l0125m_d100[:,15], color=colord100) 
ax1.plot(l0125m_d75[:,0], l0125m_d75[:,15], color=colord75) 
#ax1.plot(l0125m_d60[:,0], l0125m_d60[:,15], color=colord60)
ax1.plot(l0125m_d50[:,0], l0125m_d50[:,15], color=colord50) 
#ax1.plot(l0125m_d10[:,0], l0125m_d10[:,15], color=colord10)

ax1.semilogx(l0125_d340[:,0], l0125_d340[:,15], color=colord340, linestyle='--')
ax1.plot(l0125_d200[:,0], l0125_d200[:,15], color=colord200, linestyle='--') 
ax1.plot(l0125_d100[:,0], l0125_d100[:,15], color=colord100, linestyle='--') 
ax1.plot(l0125_d75[:,0], l0125_d75[:,15], color=colord75, linestyle='--') 
#ax1.plot(l0125_d60[:,0], l0125_d60[:,15], color=colord60, linestyle='--')
ax1.plot(l0125_d50[:,0], l0125_d50[:,15], color=colord50, linestyle='--') 
ax1.plot(l0125_d10[:,0], l0125_d10[:,15], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')

ax1.legend(loc='lower right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_ylim(-2.,1.3)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax1.set_xticklabels([])
ax1.set_title(r'$\Delta_{\mathrm{match}} = 10$')

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250m_d340[:,0], l0250m_d340[:,16], l0250m_d340[:,17], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d200[:,0], l0250m_d200[:,16], l0250m_d200[:,17], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d100[:,0], l0250m_d100[:,16], l0250m_d100[:,17], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d75[:,0], l0250m_d75[:,16], l0250m_d75[:,17], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d60[:,0], l0250m_d60[:,16], l0250m_d60[:,17], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d50[:,0], l0250m_d50[:,16], l0250m_d50[:,17], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d10[:,0], l0250m_d10[:,16], l0250m_d10[:,17], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250m_d340[:,0], l0250m_d340[:,15], color=colord340)
ax2.plot(l0250m_d200[:,0], l0250m_d200[:,15], color=colord200) 
ax2.plot(l0250m_d100[:,0], l0250m_d100[:,15], color=colord100) 
ax2.plot(l0250m_d75[:,0], l0250m_d75[:,15], color=colord75) 
#ax2.plot(l0250m_d60[:,0], l0250m_d60[:,16], color=colord60)
ax2.plot(l0250m_d50[:,0], l0250m_d50[:,15], color=colord50)
#ax2.plot(l0250m_d10[:,0], l0250m_d10[:,15], color=colord10)

ax2.semilogx(l0250_d340[:,0], l0250_d340[:,15], color=colord340, linestyle='--')
ax2.plot(l0250_d200[:,0], l0250_d200[:,15], color=colord200, linestyle='--') 
ax2.plot(l0250_d100[:,0], l0250_d100[:,15], color=colord100, linestyle='--') 
ax2.plot(l0250_d75[:,0], l0250_d75[:,15], color=colord75, linestyle='--') 
#ax2.plot(l0250_d60[:,0], l0250_d60[:,15], color=colord60, linestyle='--')
ax2.plot(l0250_d50[:,0], l0250_d50[:,15], color=colord50, linestyle='--')
#ax2.plot(l0250_d10[:,0], l0250_d10[:,15], color=colord10, linestyle='--')
ax2.plot(l0250_d60[:,0], l0250_d60[:,15], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='lower right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_xticks([5, 7, 10, 14])
ax2.set_ylim(-2.,1.3)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax2.set_xticklabels([])
ax2.set_title(r'$\Delta_{\mathrm{match}} = 60$')

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500m_d340[:,0], l0500m_d340[:,16], l0500m_d340[:,17], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d200[:,0], l0500m_d200[:,16], l0500m_d200[:,17], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d100[:,0], l0500m_d100[:,16], l0500m_d100[:,17], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d75[:,0], l0500m_d75[:,16], l0500m_d75[:,17], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d60[:,0], l0500m_d60[:,16], l0500m_d60[:,17], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d50[:,0], l0500m_d50[:,16], l0500m_d50[:,17], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d10[:,0], l0500m_d10[:,16], l0500m_d10[:,17], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500m_d340[:,0], l0500m_d340[:,15], color=colord340,
            label=r'$\Delta=340$')
ax3.plot(l0500m_d200[:,0], l0500m_d200[:,15], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500m_d100[:,0], l0500m_d100[:,15], color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500m_d75[:,0], l0500m_d75[:,15], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500m_d60[:,0], l0500m_d60[:,15], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500m_d50[:,0], l0500m_d50[:,15], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500m_d10[:,0], l0500m_d10[:,15], color=colord10,
#        label=r'$\Delta=10$')


ax3.semilogx(l0500_d340[:,0], l0500_d340[:,15], color=colord340, linestyle='--')
ax3.plot(l0500_d200[:,0], l0500_d200[:,15], color=colord200, linestyle='--')
ax3.plot(l0500_d100[:,0], l0500_d100[:,15], color=colord100, linestyle='--')
ax3.plot(l0500_d75[:,0], l0500_d75[:,15], color=colord75, linestyle='--')
#ax3.plot(l0500_d60[:,0], l0500_d60[:,15], color=colord60, linestyle='--')
ax3.plot(l0500_d50[:,0], l0500_d50[:,15], color=colord50, linestyle='--')
#ax3.plot(l0500_d10[:,0], l0500_d10[:,15], color=colord10, linestyle='--')
ax3.plot(l0500_d200[:,0], l0500_d200[:,15], 'r--',
         label=r'$\Delta=200,\mathrm{Matched}$')

ax3.legend(loc='upper left', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{V}}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-2., 1.3)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_title(r'$\Delta_{\mathrm{match}} = 200$')

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/match_mcf_cV.'+fmttag)
#plt.close(fig)

# %%
fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125m_d340[:,0], l0125m_d340[:,19], l0125m_d340[:,20], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d200[:,0], l0125m_d200[:,19], l0125m_d200[:,20], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d100[:,0], l0125m_d100[:,19], l0125m_d100[:,20], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d75[:,0], l0125m_d75[:,19], l0125m_d75[:,20], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d60[:,0], l0125m_d60[:,19], l0125m_d60[:,20], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d50[:,0], l0125m_d50[:,19], l0125m_d50[:,20], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d10[:,0], l0125m_d10[:,19], l0125m_d10[:,20], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125m_d340[:,0], l0125m_d340[:,18], color=colord340)
ax1.plot(l0125m_d200[:,0], l0125m_d200[:,18], color=colord200) 
ax1.plot(l0125m_d100[:,0], l0125m_d100[:,18], color=colord100) 
ax1.plot(l0125m_d75[:,0], l0125m_d75[:,18], color=colord75) 
#ax1.plot(l0125m_d60[:,0], l0125m_d60[:,18], color=colord60)
ax1.plot(l0125m_d50[:,0], l0125m_d50[:,18], color=colord50) 
#ax1.plot(l0125m_d10[:,0], l0125m_d10[:,18], color=colord10)

ax1.semilogx(l0125_d340[:,0], l0125_d340[:,18], color=colord340, linestyle='--')
ax1.plot(l0125_d200[:,0], l0125_d200[:,18], color=colord200, linestyle='--') 
ax1.plot(l0125_d100[:,0], l0125_d100[:,18], color=colord100, linestyle='--') 
ax1.plot(l0125_d75[:,0], l0125_d75[:,18], color=colord75, linestyle='--') 
#ax1.plot(l0125_d60[:,0], l0125_d60[:,18], color=colord60, linestyle='--')
ax1.plot(l0125_d50[:,0], l0125_d50[:,18], color=colord50, linestyle='--') 
ax1.plot(l0125_d10[:,0], l0125_d10[:,18], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$') 


ax1.legend(loc='lower right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_ylim(-0.4,0.3)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax1.set_xticklabels([])
ax1.set_title(r'$\Delta_{\mathrm{match}} = 10$')

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250m_d340[:,0], l0250m_d340[:,19], l0250m_d340[:,20], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d200[:,0], l0250m_d200[:,19], l0250m_d200[:,20], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d100[:,0], l0250m_d100[:,19], l0250m_d100[:,20], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d75[:,0], l0250m_d75[:,19], l0250m_d75[:,20], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d60[:,0], l0250m_d60[:,19], l0250m_d60[:,20], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d50[:,0], l0250m_d50[:,19], l0250m_d50[:,20], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d10[:,0], l0250m_d10[:,19], l0250m_d10[:,20], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250m_d340[:,0], l0250m_d340[:,18], color=colord340)
ax2.plot(l0250m_d200[:,0], l0250m_d200[:,18], color=colord200) 
ax2.plot(l0250m_d100[:,0], l0250m_d100[:,18], color=colord100) 
ax2.plot(l0250m_d75[:,0], l0250m_d75[:,18], color=colord75) 
#ax2.plot(l0250m_d60[:,0], l0250m_d60[:,18], color=colord60)
ax2.plot(l0250m_d50[:,0], l0250m_d50[:,18], color=colord50)
#ax2.plot(l0250m_d10[:,0], l0250m_d10[:,18], color=colord10)

ax2.semilogx(l0250_d340[:,0], l0250_d340[:,18], color=colord340, linestyle='--')
ax2.plot(l0250_d200[:,0], l0250_d200[:,18], color=colord200, linestyle='--') 
ax2.plot(l0250_d100[:,0], l0250_d100[:,18], color=colord100, linestyle='--') 
ax2.plot(l0250_d75[:,0], l0250_d75[:,18], color=colord75, linestyle='--') 
#ax2.plot(l0250_d60[:,0], l0250_d60[:,18], color=colord60, linestyle='--')
ax2.plot(l0250_d50[:,0], l0250_d50[:,18], color=colord50, linestyle='--')
#ax2.plot(l0250_d10[:,0], l0250_d10[:,18], color=colord10, linestyle='--')
ax2.plot(l0250_d60[:,0], l0250_d60[:,18], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='lower right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_ylim(-0.4, 0.3)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax2.set_xticklabels([])
ax2.set_title(r'$\Delta_{\mathrm{match}} = 60$')

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500m_d340[:,0], l0500m_d340[:,19], l0500m_d340[:,20], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d200[:,0], l0500m_d200[:,19], l0500m_d200[:,20], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d100[:,0], l0500m_d100[:,19], l0500m_d100[:,20], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d75[:,0], l0500m_d75[:,19], l0500m_d75[:,20], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d60[:,0], l0500m_d60[:,19], l0500m_d60[:,20], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d50[:,0], l0500m_d50[:,19], l0500m_d50[:,20], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d10[:,0], l0500m_d10[:,19], l0500m_d10[:,20], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500m_d340[:,0], l0500m_d340[:,18], color=colord340, 
             label=r'$\Delta=340$')
ax3.plot(l0500m_d200[:,0], l0500m_d200[:,18], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500m_d100[:,0], l0500m_d100[:,18], color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500m_d75[:,0], l0500m_d75[:,18], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500m_d60[:,0], l0500m_d60[:,18], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500m_d50[:,0], l0500m_d50[:,18], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500m_d10[:,0], l0500m_d10[:,18], color=colord10,
#         label=r'$\Delta=10$')

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,18], color=colord340, linestyle='--') 
ax3.plot(l0500_d200[:,0], l0500_d200[:,18], color=colord200, linestyle='--')
ax3.plot(l0500_d100[:,0], l0500_d100[:,18], color=colord100, linestyle='--') 
ax3.plot(l0500_d75[:,0], l0500_d75[:,18], color=colord75, linestyle='--')
#ax3.plot(l0500_d60[:,0], l0500_d60[:,18], color=colord60, linestyle='--')
ax3.plot(l0500_d50[:,0], l0500_d50[:,18], color=colord50, linestyle='--')
#ax3.plot(l0500_d10[:,0], l0500_d10[:,18], color=colord10, linestyle='--')
ax3.plot(l0500_d200[:,0], l0500_d200[:,18], 'r--',
         label=r'$\Delta=200,\mathrm{Matched}$')


ax3.legend(loc='upper left', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{c_{\mathrm{NFW}}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.4,0.3)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_title(r'$\Delta_{\mathrm{match}} = 200$')

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/match_mcf_cNFW.'+fmttag)

# %%
fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125m_d340s[:,0], l0125m_d340s[:,22], l0125m_d340s[:,23], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d200s[:,0], l0125m_d200s[:,22], l0125m_d200s[:,23], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d100s[:,0], l0125m_d100s[:,22], l0125m_d100s[:,23], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d75s[:,0], l0125m_d75s[:,22], l0125m_d75s[:,23], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d60s[:,0], l0125m_d60s[:,22], l0125m_d60s[:,23], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d50s[:,0], l0125m_d50s[:,22], l0125m_d50s[:,23], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d10s[:,0], l0125m_d10s[:,22], l0125m_d10s[:,23], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125m_d340s[:,0], l0125m_d340s[:,21], color=colord340)
ax1.plot(l0125m_d200s[:,0], l0125m_d200s[:,21], color=colord200)
ax1.plot(l0125m_d100s[:,0], l0125m_d100s[:,21], color=colord100)
ax1.plot(l0125m_d75s[:,0], l0125m_d75s[:,21], color=colord75)
#ax1.plot(l0125m_d60s[:,0], l0125m_d60s[:,21], color=colord60)
ax1.plot(l0125m_d50s[:,0], l0125m_d50s[:,21], color=colord50) 
#ax1.plot(l0125m_d10s[:,0], l0125m_d10s[:,21], color=colord10)

ax1.semilogx(l0125_d340s[:,0], l0125_d340s[:,21], color=colord340, linestyle='--')
ax1.plot(l0125_d200s[:,0], l0125_d200s[:,21], color=colord200, linestyle='--')
ax1.plot(l0125_d100s[:,0], l0125_d100s[:,21], color=colord100, linestyle='--')
ax1.plot(l0125_d75s[:,0], l0125_d75s[:,21], color=colord75, linestyle='--') 
#ax1.plot(l0125_d60s[:,0], l0125_d60s[:,21], color=colord60, linestyle='--')
ax1.plot(l0125_d50s[:,0], l0125_d50s[:,21], color=colord50, linestyle='--') 
ax1.plot(l0125_d10s[:,0], l0125_d10s[:,21], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')

ax1.legend(loc='upper right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_ylim(-0.1,1.3)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax1.set_xticklabels([])
ax1.set_title(r'$\Delta_{\mathrm{match}} = 10$')

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250m_d340s[:,0], l0250m_d340s[:,22], l0250m_d340s[:,23], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d200s[:,0], l0250m_d200s[:,22], l0250m_d200s[:,23], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d100s[:,0], l0250m_d100s[:,22], l0250m_d100s[:,23], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d75s[:,0], l0250m_d75s[:,22], l0250m_d75s[:,23], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d60s[:,0], l0250m_d60s[:,22], l0250m_d60s[:,23], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d50s[:,0], l0250m_d50s[:,22], l0250m_d50s[:,23], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d10s[:,0], l0250m_d10s[:,22], l0250m_d10s[:,23], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250m_d340s[:,0], l0250m_d340s[:,21], color=colord340)
ax2.plot(l0250m_d200s[:,0], l0250m_d200s[:,21], color=colord200) 
ax2.plot(l0250m_d100s[:,0], l0250m_d100s[:,21], color=colord100) 
ax2.plot(l0250m_d75s[:,0], l0250m_d75s[:,21], color=colord75) 
#ax2.plot(l0250m_d60s[:,0], l0250m_d60s[:,21], color=colord60)
ax2.plot(l0250m_d50s[:,0], l0250m_d50s[:,21], color=colord50)
#ax2.plot(l0250m_d10s[:,0], l0250m_d10s[:,21], color=colord10)

ax2.semilogx(l0250_d340s[:,0], l0250_d340s[:,21], color=colord340, linestyle='--')
ax2.plot(l0250_d200s[:,0], l0250_d200s[:,21], color=colord200, linestyle='--') 
ax2.plot(l0250_d100s[:,0], l0250_d100s[:,21], color=colord100, linestyle='--') 
ax2.plot(l0250_d75s[:,0], l0250_d75s[:,21], color=colord75, linestyle='--') 
#ax2.plot(l0250_d60s[:,0], l0250_d60s[:,21], color=colord60, linestyle='--')
ax2.plot(l0250_d50s[:,0], l0250_d50s[:,21], color=colord50, linestyle='--')
#ax2.plot(l0250_d10s[:,0], l0250_d10s[:,21], color=colord10, linestyle='--') 
ax2.plot(l0250_d60s[:,0], l0250_d60s[:,21], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='upper right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_ylim(-0.1,1.3)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax2.set_xticklabels([])
ax2.set_title(r'$\Delta_{\mathrm{match}} = 60$')

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500m_d340s[:,0], l0500m_d340s[:,22], l0500m_d340s[:,23], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d200s[:,0], l0500m_d200s[:,22], l0500m_d200s[:,23], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d100s[:,0], l0500m_d100s[:,22], l0500m_d100s[:,23], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d75s[:,0], l0500m_d75s[:,22], l0500m_d75s[:,23], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d60s[:,0], l0500m_d60s[:,22], l0500m_d60s[:,23], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d50s[:,0], l0500m_d50s[:,22], l0500m_d50s[:,23], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d10s[:,0], l0500m_d10s[:,22], l0500m_d10s[:,23], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500m_d340s[:,0], l0500m_d340s[:,21], color=colord340, 
             label=r'$\Delta=340$')
ax3.plot(l0500m_d200s[:,0], l0500m_d200s[:,21], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500m_d100s[:,0], l0500m_d100s[:,21], color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500m_d75s[:,0], l0500m_d75s[:,21], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500m_d60s[:,0], l0500m_d60s[:,21], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500m_d50s[:,0], l0500m_d50s[:,21], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500m_d10s[:,0], l0500m_d10s[:,21], color=colord10,
#         label=r'$\Delta=10$')

ax3.semilogx(l0500_d340s[:,0], l0500_d340s[:,21], color=colord340, linestyle='--')
ax3.plot(l0500_d200s[:,0], l0500_d200s[:,21], color=colord200, linestyle='--')
ax3.plot(l0500_d100s[:,0], l0500_d100s[:,21], color=colord100, linestyle='--')
ax3.plot(l0500_d75s[:,0], l0500_d75s[:,21], color=colord75, linestyle='--')
#ax3.plot(l0500_d60s[:,0], l0500_d60s[:,21], color=colord60, linestyle='--')
ax3.plot(l0500_d50s[:,0], l0500_d50s[:,21], color=colord50, linestyle='--')
#ax3.plot(l0500_d10s[:,0], l0500_d10s[:,21], color=colord10, linestyle='--')
ax3.plot(l0500_d200s[:,0], l0500_d200s[:,21], 'r--',
         label=r'$\Delta=200,\mathrm{Matched}$')


ax3.legend(loc='upper right', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{shape}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.1, 1.3)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_title(r'$\Delta_{\mathrm{match}} = 200$')

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/match_mcf_shape.'+fmttag)

# %%
fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125m_d340[:,0], l0125m_d340[:,25], l0125m_d340[:,26], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d200[:,0], l0125m_d200[:,25], l0125m_d200[:,26], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d100[:,0], l0125m_d100[:,25], l0125m_d100[:,26], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d75[:,0], l0125m_d75[:,25], l0125m_d75[:,26], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d60[:,0], l0125m_d60[:,25], l0125m_d60[:,26], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d50[:,0], l0125m_d50[:,25], l0125m_d50[:,26], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d10[:,0], l0125m_d10[:,25], l0125m_d10[:,26], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125m_d340[:,0], l0125m_d340[:,24], color=colord340)
ax1.plot(l0125m_d200[:,0], l0125m_d200[:,24], color=colord200) 
ax1.plot(l0125m_d100[:,0], l0125m_d100[:,24], color=colord100) 
ax1.plot(l0125m_d75[:,0], l0125m_d75[:,24], color=colord75) 
#ax1.plot(l0125m_d60[:,0], l0125m_d60[:,24], color=colord60)
ax1.plot(l0125m_d50[:,0], l0125m_d50[:,24], color=colord50) 
#ax1.plot(l0125m_d10[:,0], l0125m_d10[:,24], color=colord10)

ax1.semilogx(l0125_d340[:,0], l0125_d340[:,24], color=colord340, linestyle='--')
ax1.plot(l0125_d200[:,0], l0125_d200[:,24], color=colord200, linestyle='--') 
ax1.plot(l0125_d100[:,0], l0125_d100[:,24], color=colord100, linestyle='--') 
ax1.plot(l0125_d75[:,0], l0125_d75[:,24], color=colord75, linestyle='--') 
#ax1.plot(l0125_d60[:,0], l0125_d60[:,24], color=colord60, linestyle='--')
ax1.plot(l0125_d50[:,0], l0125_d50[:,24], color=colord50, linestyle='--') 
ax1.plot(l0125_d10[:,0], l0125_d10[:,24], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')

ax1.legend(loc='upper right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_xticks([5, 7, 10, 14])
ax1.set_ylim(-0.05,0.4)
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax1.set_xticklabels([])
ax1.set_title(r'$\Delta_{\mathrm{match}} = 10$')

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250m_d340[:,0], l0250m_d340[:,25], l0250m_d340[:,26], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d200[:,0], l0250m_d200[:,25], l0250m_d200[:,26], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d100[:,0], l0250m_d100[:,25], l0250m_d100[:,26], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d75[:,0], l0250m_d75[:,25], l0250m_d75[:,26], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d60[:,0], l0250m_d60[:,25], l0250m_d60[:,26], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d50[:,0], l0250m_d50[:,25], l0250m_d50[:,26], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d10[:,0], l0250m_d10[:,25], l0250m_d10[:,26], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250m_d340[:,0], l0250m_d340[:,24], color=colord340)
ax2.plot(l0250m_d200[:,0], l0250m_d200[:,24], color=colord200) 
ax2.plot(l0250m_d100[:,0], l0250m_d100[:,24], color=colord100) 
ax2.plot(l0250m_d75[:,0], l0250m_d75[:,24], color=colord75) 
#ax2.plot(l0250m_d60[:,0], l0250m_d60[:,24], color=colord60)
ax2.plot(l0250m_d50[:,0], l0250m_d50[:,24], color=colord50)
#ax2.plot(l0250m_d10[:,0], l0250m_d10[:,24], color=colord10)

ax2.semilogx(l0250_d340[:,0], l0250_d340[:,24], color=colord340, linestyle='--')
ax2.plot(l0250_d200[:,0], l0250_d200[:,24], color=colord200, linestyle='--') 
ax2.plot(l0250_d100[:,0], l0250_d100[:,24], color=colord100, linestyle='--') 
ax2.plot(l0250_d75[:,0], l0250_d75[:,24], color=colord75, linestyle='--') 
#ax2.plot(l0250_d60[:,0], l0250_d60[:,24], color=colord60, linestyle='--')
ax2.plot(l0250_d50[:,0], l0250_d50[:,24], color=colord50, linestyle='--')
#ax2.plot(l0250_d10[:,0], l0250_d10[:,24], color=colord10, linestyle='--')
ax2.plot(l0250_d60[:,0], l0250_d60[:,24], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='upper right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)',
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_ylim(-0.05, 0.4)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax2.set_xticklabels([])
ax2.set_title(r'$\Delta_{\mathrm{match}} = 60$')

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500m_d340[:,0], l0500m_d340[:,25], l0500m_d340[:,26], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d200[:,0], l0500m_d200[:,25], l0500m_d200[:,26], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d100[:,0], l0500m_d100[:,25], l0500m_d100[:,26], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d75[:,0], l0500m_d75[:,25], l0500m_d75[:,26], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d60[:,0], l0500m_d60[:,25], l0500m_d60[:,26], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d50[:,0], l0500m_d50[:,25], l0500m_d50[:,26], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d10[:,0], l0500m_d10[:,25], l0500m_d10[:,26], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500m_d340[:,0], l0500m_d340[:,24], color=colord340, 
             label=r'$\Delta=340$')
ax3.plot(l0500m_d200[:,0], l0500m_d200[:,24], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500m_d100[:,0], l0500m_d100[:,24], color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500m_d75[:,0], l0500m_d75[:,24], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500m_d60[:,0], l0500m_d60[:,24], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500m_d50[:,0], l0500m_d50[:,24], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500m_d10[:,0], l0500m_d10[:,24], color=colord10,
#         label=r'$\Delta=10$')

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,24], color=colord340, linestyle='--')
ax3.plot(l0500_d200[:,0], l0500_d200[:,24], color=colord200, linestyle='--')
ax3.plot(l0500_d100[:,0], l0500_d100[:,24], color=colord100, linestyle='--')
ax3.plot(l0500_d75[:,0], l0500_d75[:,24], color=colord75, linestyle='--')
#ax3.plot(l0500_d60[:,0], l0500_d60[:,24], color=colord60, linestyle='--')
ax3.plot(l0500_d50[:,0], l0500_d50[:,24], color=colord50, linestyle='--')
#ax3.plot(l0500_d10[:,0], l0500_d10[:,24], color=colord10, linestyle='--')
ax3.plot(l0500_d200[:,0], l0500_d200[:,24], 'r--',
         label=r'$\Delta=200,\mathrm{Matched}$')

ax3.legend(loc='upper right', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{spin}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.05,0.4)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_title(r'$\Delta_{\mathrm{match}} = 200$')

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/match_mcf_spin.'+fmttag)

# %%
fig = plt.figure(figsize=(6,15))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

ax1.axhline(y=0, color='k', linestyle='--')
ax1.fill_between(l0125m_d340[:,0], l0125m_d340[:,28], l0125m_d340[:,29], facecolor=colord340, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d200[:,0], l0125m_d200[:,28], l0125m_d200[:,29], facecolor=colord200, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d100[:,0], l0125m_d100[:,28], l0125m_d100[:,29], facecolor=colord100, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d75[:,0], l0125m_d75[:,28], l0125m_d75[:,29], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d60[:,0], l0125m_d60[:,28], l0125m_d60[:,29], facecolor=colord60, edgecolor='k', alpha=0.1)
ax1.fill_between(l0125m_d50[:,0], l0125m_d50[:,28], l0125m_d50[:,29], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax1.fill_between(l0125m_d10[:,0], l0125m_d10[:,28], l0125m_d10[:,29], facecolor=colord10, edgecolor='k', alpha=0.1)

ax1.semilogx(l0125m_d340[:,0], l0125m_d340[:,27], color=colord340)
ax1.plot(l0125m_d200[:,0], l0125m_d200[:,27], color=colord200) 
ax1.plot(l0125m_d100[:,0], l0125m_d100[:,27], color=colord100) 
ax1.plot(l0125m_d75[:,0], l0125m_d75[:,27], color=colord75)
#ax1.plot(l0125m_d60[:,0], l0125m_d60[:,27], color=colord60)
ax1.plot(l0125m_d50[:,0], l0125m_d50[:,27], color=colord50) 
#ax1.plot(l0125m_d10[:,0], l0125m_d10[:,27], color=colord10)

ax1.semilogx(l0125_d340[:,0], l0125_d340[:,27], color=colord340, linestyle='--')
ax1.plot(l0125_d200[:,0], l0125_d200[:,27], color=colord200, linestyle='--') 
ax1.plot(l0125_d100[:,0], l0125_d100[:,27], color=colord100, linestyle='--') 
ax1.plot(l0125_d75[:,0], l0125_d75[:,27], color=colord75, linestyle='--') 
#ax1.plot(l0125_d60[:,0], l0125_d60[:,27], color=colord60, linestyle='--')
ax1.plot(l0125_d50[:,0], l0125_d50[:,27], color=colord50, linestyle='--') 
ax1.plot(l0125_d10[:,0], l0125_d10[:,27], 'r--',
         label=r'$\Delta=10,\mathrm{Matched}$')

ax1.legend(loc='upper right', numpoints=1, title=r'Low Mass ($\geq7\times10^{10}h^{-1}M_{\odot}$)',
           prop={'size': 13}, frameon=False)
ax1.set_xlim(4,18)
ax1.set_ylim(-0.05,0.4)
ax1.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax1.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax1.set_xticklabels([])
ax1.set_title(r'$\Delta_{\mathrm{match}} = 10$')

ax2.axhline(y=0, color='k', linestyle='--')
ax2.fill_between(l0250m_d340[:,0], l0250m_d340[:,28], l0250m_d340[:,29], facecolor=colord340, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d200[:,0], l0250m_d200[:,28], l0250m_d200[:,29], facecolor=colord200, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d100[:,0], l0250m_d100[:,28], l0250m_d100[:,29], facecolor=colord100, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d75[:,0], l0250m_d75[:,28], l0250m_d75[:,29], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d60[:,0], l0250m_d60[:,28], l0250m_d60[:,29], facecolor=colord60, edgecolor='k', alpha=0.1)
ax2.fill_between(l0250m_d50[:,0], l0250m_d50[:,28], l0250m_d50[:,29], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax2.fill_between(l0250m_d10[:,0], l0250m_d10[:,28], l0250m_d10[:,29], facecolor=colord10, edgecolor='k', alpha=0.1)

ax2.semilogx(l0250m_d340[:,0], l0250m_d340[:,27], color=colord340)
ax2.plot(l0250m_d200[:,0], l0250m_d200[:,27], color=colord200) 
ax2.plot(l0250m_d100[:,0], l0250m_d100[:,27], color=colord100) 
ax2.plot(l0250m_d75[:,0], l0250m_d75[:,27], color=colord75) 
#ax2.plot(l0250m_d60[:,0], l0250m_d60[:,27], color=colord60)
ax2.plot(l0250m_d50[:,0], l0250m_d50[:,27], color=colord50)
#ax2.plot(l0250m_d10[:,0], l0250m_d10[:,27], color=colord10)

ax2.semilogx(l0250_d340[:,0], l0250_d340[:,27], color=colord340, linestyle='--')
ax2.plot(l0250_d200[:,0], l0250_d200[:,27], color=colord200, linestyle='--') 
ax2.plot(l0250_d100[:,0], l0250_d100[:,27], color=colord100, linestyle='--') 
ax2.plot(l0250_d75[:,0], l0250_d75[:,27], color=colord75, linestyle='--') 
#ax2.plot(l0250_d60[:,0], l0250_d60[:,27], color=colord60, linestyle='--')
ax2.plot(l0250_d50[:,0], l0250_d50[:,27], color=colord50, linestyle='--')
#ax2.plot(l0250_d10[:,0], l0250_d10[:,27], color=colord10, linestyle='--')
ax2.plot(l0250_d60[:,0], l0250_d60[:,27], 'r--',
         label=r'$\Delta=60,\mathrm{Matched}$')

ax2.legend(loc='upper right', numpoints=1, title=r'Mid Mass ($\geq7\times10^{11}h^{-1}M_{\odot}$)', 
           prop={'size': 13}, frameon=False)
ax2.set_xlim(4,18)
ax2.set_ylim(-0.05,0.4)
ax2.set_xticks([5, 7, 10, 14])
#ax2.set_ylim(-0.02,0.02)
#ax2.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax2.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax2.set_xticklabels([])
ax2.set_title(r'$\Delta_{\mathrm{match}} = 60$')

ax3.axhline(y=0, color='k', linestyle='--')
ax3.fill_between(l0500m_d340[:,0], l0500m_d340[:,28], l0500m_d340[:,29], facecolor=colord340, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d200[:,0], l0500m_d200[:,28], l0500m_d200[:,29], facecolor=colord200, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d100[:,0], l0500m_d100[:,28], l0500m_d100[:,29], facecolor=colord100, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d75[:,0], l0500m_d75[:,28], l0500m_d75[:,29], facecolor=colord75, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d60[:,0], l0500m_d60[:,28], l0500m_d60[:,29], facecolor=colord60, edgecolor='k', alpha=0.1)
ax3.fill_between(l0500m_d50[:,0], l0500m_d50[:,28], l0500m_d50[:,29], facecolor=colord50, edgecolor='k', alpha=0.1)
#ax3.fill_between(l0500m_d10[:,0], l0500m_d10[:,28], l0500m_d10[:,29], facecolor=colord10, edgecolor='k', alpha=0.1)

ax3.semilogx(l0500m_d340[:,0], l0500m_d340[:,27], color=colord340, 
             label=r'$\Delta=340$')
ax3.plot(l0500m_d200[:,0], l0500m_d200[:,27], color=colord200, 
         label=r'$\Delta=200$')
ax3.plot(l0500m_d100[:,0], l0500m_d100[:,27], color=colord100, 
         label=r'$\Delta=100$')
ax3.plot(l0500m_d75[:,0], l0500m_d75[:,27], color=colord75, 
         label=r'$\Delta=75$')
#ax3.plot(l0500m_d60[:,0], l0500m_d60[:,27], color=colord60,
#         label=r'$\Delta=60$')
ax3.plot(l0500m_d50[:,0], l0500m_d50[:,27], color=colord50, 
         label=r'$\Delta=50$')
#ax3.plot(l0500m_d10[:,0], l0500m_d10[:,0], color=colord10,
#         label=r'$\Delta=10$')

ax3.semilogx(l0500_d340[:,0], l0500_d340[:,27], color=colord340, linestyle='--')
ax3.plot(l0500_d200[:,0], l0500_d200[:,27], color=colord200, linestyle='--')
ax3.plot(l0500_d100[:,0], l0500_d100[:,27], color=colord100, linestyle='--')
ax3.plot(l0500_d75[:,0], l0500_d75[:,27], color=colord75, linestyle='--')
#ax3.plot(l0500_d60[:,0], l0500_d60[:,27], color=colord60, linestyle='--')
ax3.plot(l0500_d50[:,0], l0500_d50[:,27], color=colord50, linestyle='--')
#ax3.plot(l0500_d10[:,0], l0500_d10[:,27], color=colord10, linestyle='--')
ax3.plot(l0500_d200[:,0], l0500_d200[:,27], 'r--',
         label=r'$\Delta=200,\mathrm{Matched}$')

 
ax3.legend(loc='upper right', numpoints=1, title=r'High Mass ($\geq4\times10^{12}h^{-1}M_{\odot}$)', 
           ncol=2, prop={'size': 13}, frameon=False)
#ax2.set_ylim(-0.02,0.02)
ax3.set_xlabel(r'$r \ (h^{-1} \mathrm{Mpc})$')
ax3.set_ylabel(r'$\mathcal{M}_{\mathrm{Nsat}}$')
ax3.set_xlim(4,18)
ax3.set_ylim(-0.05,0.4)
ax3.set_xticks([5, 7, 10, 14])
ax3.set_xticklabels(['5', '7', '10', '14'])
ax3.set_title(r'$\Delta_{\mathrm{match}} = 200$')

fig.tight_layout(pad=0.1)
plt.savefig('./FIGS/match_mcf_nsat.'+fmttag)

# %%
# here we are going to make our plot comparing our best-fit radius to the splashback radius as a function of mass.
# as best we can at least.

m_our = [7e10, 7e11, 4e12]
rratio_our = [ (200./20)**(1./3), (200./60)**(1./3), 1]
rratio_their = [1.27, 1.26 ,1.125, 1]
m_their = [1e10, 1e12, 1e14, 1e15]

plt.semilogx(m_our, rratio_our, 'bo', label=r'best $\Delta$', ms=10)
plt.semilogx(m_their, rratio_their, 'ro', label=r'splashback', ms=10)
plt.xlabel(r'$M_{\mathrm{200m}} (h^{-1}M_{\odot})$')
plt.ylabel(r'$r / r_{200}$')
plt.xlim(8e9,1.1e16)
plt.ylim(0.8, 2.2)
plt.legend(loc='upper right', numpoints=1, prop={'size': 13})

plt.tight_layout(pad=0.1)
plt.savefig('./FIGS/test_splashback.'+fmttag)

print rratio_our
# Out:
# [2.154434690031884, 1.4938015821857216, 1]
